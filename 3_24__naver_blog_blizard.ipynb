# %%
# client ID : "NBIdLcJq6KfcFvAXcdRx"
# client Secret : "CBPAWvsX12"

# %%
import urllib.request

client_id ="NBIdLcJq6KfcFvAXcdRx"
client_secret = "CBPAWvsX12"
encText = urllib.parse.quote("블리자드")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
response.getcode()
# Out:
# 200

# %%
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Wed, 24 Mar 2021 20:41:10 +0900",
# "total": 162586,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "디아블로2 레저렉션 개발자 인터뷰 - <b>블리자드</b>의 리마스터는... ",
# "link": "https:\/\/blog.naver.com\/ha_tak?Redirect=Log&logNo=222250767802",
# "description": "<b>블리자드</b>의 30주년을 맞이하는 행사였기도 했고, <b>블리자드</b> 역시 과거의 영광과 재미를 추억하면서 <b>블리자드</b> IP를 활용한 게임들 중 마지막 리마스터를 선보였기 때문이다. <b>블리자드</b>가 마지막으로 리마스터하는... ",
# "bloggername": "리뷰빌런 하텍",
# "bloggerlink": "https://blog.naver.com/ha_tak",
# "postdate": "20210221"
#
# },
# {
# "title": "디즈니월드 여행후기 (매직킹덤, <b>블리자드</b>비치)",
# "link": "https:\/\/blog.naver.com\/busan_fish?Redirect=Log&logNo=222275990259",
# "description": "- 카페에 남긴 후기 글이라, 말투가 소름 돋는 점 양해 바랍니다 디즈니월드, 매직킹덤, <b>블리자드</b>비치... <b>블리자드</b> 비치 - 디즈니월드에 가서 누가 워터파크를 가나- 생각 하실텐데 저희는 아이가 어려서... ",
# "bloggername": "나는시간이많은어른이되고싶었습니다",
# "bloggerlink": "https://blog.naver.com/busan_fish",
# "postdate": "20210315"
#
# },
# {
# "title": "2 이후 리마스터 게임 없을 것...향후 30년이 <b>블리자드</b> 전성기",
# "link": "https:\/\/blog.naver.com\/tearhunter?Redirect=Log&logNo=222250473378",
# "description": "<b>블리자드</b>가 30주년을 기념해 클래식 게임을 모아놓은 '아케이드 컬렉션'을 출시했다. [출처: <b>블리자드</b>코리아] <b>블리자드</b>가 매년 개최하는 커뮤니티 축제 '블리즈컨'을 20일 개막했다. 올해는 코로나19로 인해... ",
# "bloggername": "웹진 [Coin Choice]",
# "bloggerlink": "https://blog.naver.com/tearhunter",
# "postdate": "20210220"
#
# },
# {
# "title": "<b>블리자드</b> 콘스네이크 아가 입양했습니다",
# "link": "https:\/\/blog.naver.com\/artdodam?Redirect=Log&logNo=222226944156",
# "description": "지렁이같이 생긴 ㅋㅋㅋ <b>블리자드</b> 콘스네이크 아가 모습입니다. 집에 도착하자마자 촬영했어요. 하... 잡소리는 이쯤하고 우리 이쁨돋는 <b>블리자드</b> 콘스네이크 친구를 보실까요! 확대하니 뭔가 포스... ",
# "bloggername": "도담이네 작은 집 :)",
# "bloggerlink": "https://blog.naver.com/artdodam",
# "postdate": "20210201"
#
# },
# {
# "title": "디아블로 20주년 흉상 피규어 &amp; <b>블리자드</b>기어 스토어 직구 방법",
# "link": "https:\/\/blog.naver.com\/doek11?Redirect=Log&logNo=222227718191",
# "description": "(다행히 재고가 많이 있더라) 그런데 그동안 <b>블리자드</b>기어 스토어는 파나틱스(Fanatics)라는 업체에서... <b>블리자드</b> 기어 스토어 권한이 파나틱스로 넘어가면서 크게 달라진 점은 국제 배송비가 아닐까... ",
# "bloggername": "네오필 블로그",
# "bloggerlink": "https://blog.naver.com/doek11",
# "postdate": "20210201"
#
# },
# {
# "title": "오버워치 디바 한복 공개 &amp; <b>블리자드</b> 한국 사랑 대단해",
# "link": "https:\/\/blog.naver.com\/cowai?Redirect=Log&logNo=222253599771",
# "description": "원본 일러스트 풀버전은 <b>블리자드</b> 공식 홈페이지 '링크'에서 확인할 수 있다. 디바 한복 소개 영상이 큰 화제를 불러일으키고 있는 건 도스피님의 뛰어난 예술 작품 때문이기도 하지만 <b>블리자드</b>가 한국을... ",
# "bloggername": "cowai 코와잉",
# "bloggerlink": "https://blog.naver.com/cowai",
# "postdate": "20210223"
#
# },
# {
# "title": "[스마정복기] <b>블리자드</b>에서의 마지막 페이지",
# "link": "https:\/\/blog.naver.com\/syl08001?Redirect=Log&logNo=222111078266",
# "description": "(오늘 이 글을 쓰기 약 한 달 전 나는 <b>블리자드</b>를 퇴사했다) 2019년부터 <b>블리자드</b> 코리아 e스포츠 전체를 관리하는 역할을 하던 필자는 2020년부터 아시아-태평양 지역 e스포츠까지 총괄했다. <b>블리자드</b>가 지닌... ",
# "bloggername": "스포츠마케팅쪼개기, [스][마][쪼]맨",
# "bloggerlink": "https://blog.naver.com/syl08001",
# "postdate": "20201009"
#
# },
# {
# "title": "2021 <b>블리자드</b> 블리즈컨 디아블로2 리저렉션의 등장",
# "link": "https:\/\/blog.naver.com\/kum8875?Redirect=Log&logNo=222251494297",
# "description": "#블리즈컨 #2021블리즈컨 #디아블로 #<b>블리자드</b> #디아블로2 #디아블로2리저렉션 #디아블로2예약판매 안녕하세요. 우산블로그입니다. 안녕하세요. 우산 블로그의 우산 입니다. 이번 21년 <b>블리자드</b> 블리즈컨이... ",
# "bloggername": "우산의 IT블로그",
# "bloggerlink": "https://blog.naver.com/kum8875",
# "postdate": "20210221"
#
# },
# {
# "title": "<b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?",
# "link": "https:\/\/blog.naver.com\/xenicsholic?Redirect=Log&logNo=222245660616",
# "description": "<b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까? 안녕하세요. 제닉스입니다. 길었던 설... 이번 시간에는 앞으로 5일 남은 전 세계를 대표하는 유명 게임회사 <b>블리자드</b>에서 여는 '2021 블리즈컨'에... ",
# "bloggername": "::: 제닉스 공식 네이버 블로그 :::",
# "bloggerlink": "https://blog.naver.com/xenicsholic",
# "postdate": "20210216"
#
# },
# {
# "title": "<b>블리자드</b>가 홍콩 프로게이머 우승 상금 몰수한 이유",
# "link": "https:\/\/blog.naver.com\/tech-plus?Redirect=Log&logNo=221673454471",
# "description": "스타크래프트, 오버워치 등으로 유명한 글로벌 게임사 '<b>블리자드</b>'의 최근 행동도 중국 정부의 눈밖에 나지 않으려는 시도이자 중국 시장을 잃지 않으려는 몸부림이었을까. 최근 외신에 따르면, <b>블리자드</b>는... ",
# "bloggername": "테크플러스",
# "bloggerlink": "https://blog.naver.com/tech-plus",
# "postdate": "20191010"
#
# }
# ]
# }

# %%
# def gen_search_

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
import json
import datetime
def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    response = urllib.request.urlopen(request)
    
    print('[%s] url request success' %datetime.datetime.now())
    
    return json.loads(response.read().decode('utf-8'))

# %%
client_id ="NBIdLcJq6KfcFvAXcdRx"
client_secret = "CBPAWvsX12"

url = gen_search_url('blog','블리자드',1,10)
one_result = get_result_onpage(url)
# Out:
# [2021-03-24 20:48:06.579627] url request success

# %%
one_result
# Out:
# {'lastBuildDate': 'Wed, 24 Mar 2021 20:48:06 +0900',
#  'total': 162587,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '디아블로2 레저렉션 개발자 인터뷰 - <b>블리자드</b>의 리마스터는... ',
#    'link': 'https://blog.naver.com/ha_tak?Redirect=Log&logNo=222250767802',
#    'description': '<b>블리자드</b>의 30주년을 맞이하는 행사였기도 했고, <b>블리자드</b> 역시 과거의 영광과 재미를 추억하면서 <b>블리자드</b> IP를 활용한 게임들 중 마지막 리마스터를 선보였기 때문이다. <b>블리자드</b>가 마지막으로 리마스터하는... ',
#    'bloggername': '리뷰빌런 하텍',
#    'bloggerlink': 'https://blog.naver.com/ha_tak',
#    'postdate': '20210221'},
#   {'title': '디즈니월드 여행후기 (매직킹덤, <b>블리자드</b>비치)',
#    'link': 'https://blog.naver.com/busan_fish?Redirect=Log&logNo=222275990259',
#    'description': '- 카페에 남긴 후기 글이라, 말투가 소름 돋는 점 양해 바랍니다 디즈니월드, 매직킹덤, <b>블리자드</b>비치... <b>블리자드</b> 비치 - 디즈니월드에 가서 누가 워터파크를 가나- 생각 하실텐데 저희는 아이가 어려서... ',
#    'bloggername': '나는시간이많은어른이되고싶었습니다',
#    'bloggerlink': 'https://blog.naver.com/busan_fish',
#    'postdate': '20210315'},
#   {'title': '2 이후 리마스터 게임 없을 것...향후 30년이 <b>블리자드</b> 전성기',
#    'link': 'https://blog.naver.com/tearhunter?Redirect=Log&logNo=222250473378',
#    'description': "<b>블리자드</b>가 30주년을 기념해 클래식 게임을 모아놓은 '아케이드 컬렉션'을 출시했다. [출처: <b>블리자드</b>코리아] <b>블리자드</b>가 매년 개최하는 커뮤니티 축제 '블리즈컨'을 20일 개막했다. 올해는 코로나19로 인해... ",
#    'bloggername': '웹진 [Coin Choice]',
#    'bloggerlink': 'https://blog.naver.com/tearhunter',
#    'postdate': '20210220'},
#   {'title': '<b>블리자드</b> 콘스네이크 아가 입양했습니다',
#    'link': 'https://blog.naver.com/artdodam?Redirect=Log&logNo=222226944156',
#    'description': '지렁이같이 생긴 ㅋㅋㅋ <b>블리자드</b> 콘스네이크 아가 모습입니다. 집에 도착하자마자 촬영했어요. 하... 잡소리는 이쯤하고 우리 이쁨돋는 <b>블리자드</b> 콘스네이크 친구를 보실까요! 확대하니 뭔가 포스... ',
#    'bloggername': '도담이네 작은 집 :)',
#    'bloggerlink': 'https://blog.naver.com/artdodam',
#    'postdate': '20210201'},
#   {'title': '디아블로 20주년 흉상 피규어 &amp; <b>블리자드</b>기어 스토어 직구 방법',
#    'link': 'https://blog.naver.com/doek11?Redirect=Log&logNo=222227718191',
#    'description': '(다행히 재고가 많이 있더라) 그런데 그동안 <b>블리자드</b>기어 스토어는 파나틱스(Fanatics)라는 업체에서... <b>블리자드</b> 기어 스토어 권한이 파나틱스로 넘어가면서 크게 달라진 점은 국제 배송비가 아닐까... ',
#    'bloggername': '네오필 블로그',
#    'bloggerlink': 'https://blog.naver.com/doek11',
#    'postdate': '20210201'},
#   {'title': '오버워치 디바 한복 공개 &amp; <b>블리자드</b> 한국 사랑 대단해',
#    'link': 'https://blog.naver.com/cowai?Redirect=Log&logNo=222253599771',
#    'description': "원본 일러스트 풀버전은 <b>블리자드</b> 공식 홈페이지 '링크'에서 확인할 수 있다. 디바 한복 소개 영상이 큰 화제를 불러일으키고 있는 건 도스피님의 뛰어난 예술 작품 때문이기도 하지만 <b>블리자드</b>가 한국을... ",
#    'bloggername': 'cowai 코와잉',
#    'bloggerlink': 'https://blog.naver.com/cowai',
#    'postdate': '20210223'},
#   {'title': '[스마정복기] <b>블리자드</b>에서의 마지막 페이지',
#    'link': 'https://blog.naver.com/syl08001?Redirect=Log&logNo=222111078266',
#    'description': '(오늘 이 글을 쓰기 약 한 달 전 나는 <b>블리자드</b>를 퇴사했다) 2019년부터 <b>블리자드</b> 코리아 e스포츠 전체를 관리하는 역할을 하던 필자는 2020년부터 아시아-태평양 지역 e스포츠까지 총괄했다. <b>블리자드</b>가 지닌... ',
#    'bloggername': '스포츠마케팅쪼개기, [스][마][쪼]맨',
#    'bloggerlink': 'https://blog.naver.com/syl08001',
#    'postdate': '20201009'},
#   {'title': '2021 <b>블리자드</b> 블리즈컨 디아블로2 리저렉션의 등장',
#    'link': 'https://blog.naver.com/kum8875?Redirect=Log&logNo=222251494297',
#    'description': '#블리즈컨 #2021블리즈컨 #디아블로 #<b>블리자드</b> #디아블로2 #디아블로2리저렉션 #디아블로2예약판매 안녕하세요. 우산블로그입니다. 안녕하세요. 우산 블로그의 우산 입니다. 이번 21년 <b>블리자드</b> 블리즈컨이... ',
#    'bloggername': '우산의 IT블로그',
#    'bloggerlink': 'https://blog.naver.com/kum8875',
#    'postdate': '20210221'},
#   {'title': '<b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?',
#    'link': 'https://blog.naver.com/xenicsholic?Redirect=Log&logNo=222245660616',
#    'description': "<b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까? 안녕하세요. 제닉스입니다. 길었던 설... 이번 시간에는 앞으로 5일 남은 전 세계를 대표하는 유명 게임회사 <b>블리자드</b>에서 여는 '2021 블리즈컨'에... ",
#    'bloggername': '::: 제닉스 공식 네이버 블로그 :::',
#    'bloggerlink': 'https://blog.naver.com/xenicsholic',
#    'postdate': '20210216'},
#   {'title': '<b>블리자드</b>가 홍콩 프로게이머 우승 상금 몰수한 이유',
#    'link': 'https://blog.naver.com/tech-plus?Redirect=Log&logNo=221673454471',
#    'description': "스타크래프트, 오버워치 등으로 유명한 글로벌 게임사 '<b>블리자드</b>'의 최근 행동도 중국 정부의 눈밖에 나지 않으려는 시도이자 중국 시장을 잃지 않으려는 몸부림이었을까. 최근 외신에 따르면, <b>블리자드</b>는... ",
#    'bloggername': '테크플러스',
#    'bloggerlink': 'https://blog.naver.com/tech-plus',
#    'postdate': '20191010'}]}

# %%
for i in one_result['items']:
    i['title'] = i['title'].replace('<b>','')
    i['title'] = i['title'].replace('</b>','')
    print(i['title'])
# Out:
# 디아블로2 레저렉션 개발자 인터뷰 - 블리자드의 리마스터는...
# 디즈니월드 여행후기 (매직킹덤, 블리자드비치)
# 2 이후 리마스터 게임 없을 것...향후 30년이 블리자드 전성기
# 블리자드 콘스네이크 아가 입양했습니다
# 디아블로 20주년 흉상 피규어 &amp; 블리자드기어 스토어 직구 방법
# 오버워치 디바 한복 공개 &amp; 블리자드 한국 사랑 대단해
# [스마정복기] 블리자드에서의 마지막 페이지
# 2021 블리자드 블리즈컨 디아블로2 리저렉션의 등장
# 블리자드 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?
# 블리자드가 홍콩 프로게이머 우승 상금 몰수한 이유

# %%
import pandas as pd

def get_fields(json_data):
    title = [each['title'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    description = [each['description'] for each in json_data['items']]
    postdate = [each['postdate'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'description' : description,
        'postdate' : postdate,
        'link' : link
    },
    columns=['title','description','postdate','link'])
    
    return result_pd

# %%
one_result
# Out:
# {'lastBuildDate': 'Wed, 24 Mar 2021 20:48:06 +0900',
#  'total': 162587,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '디아블로2 레저렉션 개발자 인터뷰 - 블리자드의 리마스터는... ',
#    'link': 'https://blog.naver.com/ha_tak?Redirect=Log&logNo=222250767802',
#    'description': '<b>블리자드</b>의 30주년을 맞이하는 행사였기도 했고, <b>블리자드</b> 역시 과거의 영광과 재미를 추억하면서 <b>블리자드</b> IP를 활용한 게임들 중 마지막 리마스터를 선보였기 때문이다. <b>블리자드</b>가 마지막으로 리마스터하는... ',
#    'bloggername': '리뷰빌런 하텍',
#    'bloggerlink': 'https://blog.naver.com/ha_tak',
#    'postdate': '20210221'},
#   {'title': '디즈니월드 여행후기 (매직킹덤, 블리자드비치)',
#    'link': 'https://blog.naver.com/busan_fish?Redirect=Log&logNo=222275990259',
#    'description': '- 카페에 남긴 후기 글이라, 말투가 소름 돋는 점 양해 바랍니다 디즈니월드, 매직킹덤, <b>블리자드</b>비치... <b>블리자드</b> 비치 - 디즈니월드에 가서 누가 워터파크를 가나- 생각 하실텐데 저희는 아이가 어려서... ',
#    'bloggername': '나는시간이많은어른이되고싶었습니다',
#    'bloggerlink': 'https://blog.naver.com/busan_fish',
#    'postdate': '20210315'},
#   {'title': '2 이후 리마스터 게임 없을 것...향후 30년이 블리자드 전성기',
#    'link': 'https://blog.naver.com/tearhunter?Redirect=Log&logNo=222250473378',
#    'description': "<b>블리자드</b>가 30주년을 기념해 클래식 게임을 모아놓은 '아케이드 컬렉션'을 출시했다. [출처: <b>블리자드</b>코리아] <b>블리자드</b>가 매년 개최하는 커뮤니티 축제 '블리즈컨'을 20일 개막했다. 올해는 코로나19로 인해... ",
#    'bloggername': '웹진 [Coin Choice]',
#    'bloggerlink': 'https://blog.naver.com/tearhunter',
#    'postdate': '20210220'},
#   {'title': '블리자드 콘스네이크 아가 입양했습니다',
#    'link': 'https://blog.naver.com/artdodam?Redirect=Log&logNo=222226944156',
#    'description': '지렁이같이 생긴 ㅋㅋㅋ <b>블리자드</b> 콘스네이크 아가 모습입니다. 집에 도착하자마자 촬영했어요. 하... 잡소리는 이쯤하고 우리 이쁨돋는 <b>블리자드</b> 콘스네이크 친구를 보실까요! 확대하니 뭔가 포스... ',
#    'bloggername': '도담이네 작은 집 :)',
#    'bloggerlink': 'https://blog.naver.com/artdodam',
#    'postdate': '20210201'},
#   {'title': '디아블로 20주년 흉상 피규어 &amp; 블리자드기어 스토어 직구 방법',
#    'link': 'https://blog.naver.com/doek11?Redirect=Log&logNo=222227718191',
#    'description': '(다행히 재고가 많이 있더라) 그런데 그동안 <b>블리자드</b>기어 스토어는 파나틱스(Fanatics)라는 업체에서... <b>블리자드</b> 기어 스토어 권한이 파나틱스로 넘어가면서 크게 달라진 점은 국제 배송비가 아닐까... ',
#    'bloggername': '네오필 블로그',
#    'bloggerlink': 'https://blog.naver.com/doek11',
#    'postdate': '20210201'},
#   {'title': '오버워치 디바 한복 공개 &amp; 블리자드 한국 사랑 대단해',
#    'link': 'https://blog.naver.com/cowai?Redirect=Log&logNo=222253599771',
#    'description': "원본 일러스트 풀버전은 <b>블리자드</b> 공식 홈페이지 '링크'에서 확인할 수 있다. 디바 한복 소개 영상이 큰 화제를 불러일으키고 있는 건 도스피님의 뛰어난 예술 작품 때문이기도 하지만 <b>블리자드</b>가 한국을... ",
#    'bloggername': 'cowai 코와잉',
#    'bloggerlink': 'https://blog.naver.com/cowai',
#    'postdate': '20210223'},
#   {'title': '[스마정복기] 블리자드에서의 마지막 페이지',
#    'link': 'https://blog.naver.com/syl08001?Redirect=Log&logNo=222111078266',
#    'description': '(오늘 이 글을 쓰기 약 한 달 전 나는 <b>블리자드</b>를 퇴사했다) 2019년부터 <b>블리자드</b> 코리아 e스포츠 전체를 관리하는 역할을 하던 필자는 2020년부터 아시아-태평양 지역 e스포츠까지 총괄했다. <b>블리자드</b>가 지닌... ',
#    'bloggername': '스포츠마케팅쪼개기, [스][마][쪼]맨',
#    'bloggerlink': 'https://blog.naver.com/syl08001',
#    'postdate': '20201009'},
#   {'title': '2021 블리자드 블리즈컨 디아블로2 리저렉션의 등장',
#    'link': 'https://blog.naver.com/kum8875?Redirect=Log&logNo=222251494297',
#    'description': '#블리즈컨 #2021블리즈컨 #디아블로 #<b>블리자드</b> #디아블로2 #디아블로2리저렉션 #디아블로2예약판매 안녕하세요. 우산블로그입니다. 안녕하세요. 우산 블로그의 우산 입니다. 이번 21년 <b>블리자드</b> 블리즈컨이... ',
#    'bloggername': '우산의 IT블로그',
#    'bloggerlink': 'https://blog.naver.com/kum8875',
#    'postdate': '20210221'},
#   {'title': '블리자드 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?',
#    'link': 'https://blog.naver.com/xenicsholic?Redirect=Log&logNo=222245660616',
#    'description': "<b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까? 안녕하세요. 제닉스입니다. 길었던 설... 이번 시간에는 앞으로 5일 남은 전 세계를 대표하는 유명 게임회사 <b>블리자드</b>에서 여는 '2021 블리즈컨'에... ",
#    'bloggername': '::: 제닉스 공식 네이버 블로그 :::',
#    'bloggerlink': 'https://blog.naver.com/xenicsholic',
#    'postdate': '20210216'},
#   {'title': '블리자드가 홍콩 프로게이머 우승 상금 몰수한 이유',
#    'link': 'https://blog.naver.com/tech-plus?Redirect=Log&logNo=221673454471',
#    'description': "스타크래프트, 오버워치 등으로 유명한 글로벌 게임사 '<b>블리자드</b>'의 최근 행동도 중국 정부의 눈밖에 나지 않으려는 시도이자 중국 시장을 잃지 않으려는 몸부림이었을까. 최근 외신에 따르면, <b>블리자드</b>는... ",
#    'bloggername': '테크플러스',
#    'bloggerlink': 'https://blog.naver.com/tech-plus',
#    'postdate': '20191010'}]}

# %%
get_fields(one_result)
# Out:
#                                      title  \
# 0     디아블로2 레저렉션 개발자 인터뷰 - 블리자드의 리마스터는...
# 1                디즈니월드 여행후기 (매직킹덤, 블리자드비치)
# 2     2 이후 리마스터 게임 없을 것...향후 30년이 블리자드 전성기
# 3                     블리자드 콘스네이크 아가 입양했습니다
# 4  디아블로 20주년 흉상 피규어 &amp; 블리자드기어 스토어 직구 방법
# 5       오버워치 디바 한복 공개 &amp; 블리자드 한국 사랑 대단해
# 6                  [스마정복기] 블리자드에서의 마지막 페이지
# 7            2021 블리자드 블리즈컨 디아블로2 리저렉션의 등장
# 8  블리자드 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?
# 9              블리자드가 홍콩 프로게이머 우승 상금 몰수한 이유
#
#                                          description  postdate  \
# 0  <b>블리자드</b>의 30주년을 맞이하는 행사였기도 했고, <b>블리자드</b> ...  20210221
# 1  - 카페에 남긴 후기 글이라, 말투가 소름 돋는 점 양해 바랍니다 디즈니월드, 매직...  20210315
# 2  <b>블리자드</b>가 30주년을 기념해 클래식 게임을 모아놓은 '아케이드 컬렉션'...  20210220
# 3  지렁이같이 생긴 ㅋㅋㅋ <b>블리자드</b> 콘스네이크 아가 모습입니다. 집에 도착...  20210201
# 4  (다행히 재고가 많이 있더라) 그런데 그동안 <b>블리자드</b>기어 스토어는 파나...  20210201
# 5  원본 일러스트 풀버전은 <b>블리자드</b> 공식 홈페이지 '링크'에서 확인할 수 ...  20210223
# 6  (오늘 이 글을 쓰기 약 한 달 전 나는 <b>블리자드</b>를 퇴사했다) 2019...  20201009
# 7  #블리즈컨 #2021블리즈컨 #디아블로 #<b>블리자드</b> #디아블로2 #디아블...  20210221
# 8  <b>블리자드</b> 2021 블리즈컨, 2월 20일 개최! 디아블로 소식 나올까?...  20210216
# 9  스타크래프트, 오버워치 등으로 유명한 글로벌 게임사 '<b>블리자드</b>'의 최근...  20191010
#
#                                                 link
# 0  https://blog.naver.com/ha_tak?Redirect=Log&log...
# 1  https://blog.naver.com/busan_fish?Redirect=Log...
# 2  https://blog.naver.com/tearhunter?Redirect=Log...
# 3  https://blog.naver.com/artdodam?Redirect=Log&l...
# 4  https://blog.naver.com/doek11?Redirect=Log&log...
# 5  https://blog.naver.com/cowai?Redirect=Log&logN...
# 6  https://blog.naver.com/syl08001?Redirect=Log&l...
# 7  https://blog.naver.com/kum8875?Redirect=Log&lo...
# 8  https://blog.naver.com/xenicsholic?Redirect=Lo...
# 9  https://blog.naver.com/tech-plus?Redirect=Log&...

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>','')
    input_str = input_str.replace('</b>','')
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    description = [delete_tag(each['description']) for each in json_data['items']]
    postdate = [each['postdate'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'description' : description,
        'postdate' : postdate,
        'link' : link
    },
    columns=['title','description','postdate','link'])
    
    return result_pd

# %%
result_mol = []

for i in range(1,1000,100):
    url = gen_search_url('blog','블리자드',i,100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
# Out:
# [2021-03-24 20:56:38.086406] url request success
# [2021-03-24 20:56:38.214093] url request success
# [2021-03-24 20:56:38.316136] url request success
# [2021-03-24 20:56:38.421651] url request success
# [2021-03-24 20:56:38.527866] url request success
# [2021-03-24 20:56:38.645965] url request success
# [2021-03-24 20:56:39.600880] url request success
# [2021-03-24 20:56:39.712824] url request success
# [2021-03-24 20:56:40.828079] url request success
# [2021-03-24 20:56:40.935464] url request success

# %%
result_mol = pd.concat(result_mol)

# %%
result_mol
# Out:
#                                           title  \
# 0          디아블로2 레저렉션 개발자 인터뷰 - 블리자드의 리마스터는...
# 1                     디즈니월드 여행후기 (매직킹덤, 블리자드비치)
# 2          2 이후 리마스터 게임 없을 것...향후 30년이 블리자드 전성기
# 3                          블리자드 콘스네이크 아가 입양했습니다
# 4       디아블로 20주년 흉상 피규어 &amp; 블리자드기어 스토어 직구 방법
# ..                                          ...
# 95                       아이 진짜 망할 블리자드 ㅡㅡ(오버워치)
# 96  알렌 브렉 블리자드 사장 &quot;지나온 30년 처럼 앞으로 30년도...
# 97                 클린해진 오버워치 시즌11, 블리자드 아주 칭찬해!
# 98         [DS]'이나즈마 일레븐 2 위협의 침략자 파이어/블리자드...
# 99                           +380 뉴욕, 블리자드, 성공적
#
#                                           description  postdate  \
# 0   블리자드의 30주년을 맞이하는 행사였기도 했고, 블리자드 역시 과거의 영광과 재미를...  20210221
# 1   - 카페에 남긴 후기 글이라, 말투가 소름 돋는 점 양해 바랍니다 디즈니월드, 매직...  20210315
# 2   블리자드가 30주년을 기념해 클래식 게임을 모아놓은 '아케이드 컬렉션'을 출시했다....  20210220
# 3   지렁이같이 생긴 ㅋㅋㅋ 블리자드 콘스네이크 아가 모습입니다. 집에 도착하자마자 촬영...  20210201
# 4   (다행히 재고가 많이 있더라) 그런데 그동안 블리자드기어 스토어는 파나틱스(Fana...  20210201
# ..                                                ...       ...
# 95  지금 블리자드가 긴급공지 띄우긴 했는데 외국게임이라 시간 좀 걸리겠지. 모이라도 힐...  20191211
# 96  알렌 브렉 블리자드 사장 &quot;지나온 30년 처럼 앞으로 30년도 같은 철학으...  20210220
# 97  중요한 문제, 블리자드는 오버워치 시즌 11에서는 획기적인 방안으로 문제를 해결해냈...  20180719
# 98  닌텐도DS용 소프트 '이나즈마 일레븐 2 위협의 침략자 파이어/블리자드'의 거의 전...  20100623
# 99  블리자드 자연 앞에서 닌겐은 얼마나 무기력한가. 사실 지금 겪는 이 모든 멘붕엔 이...  20160125
#
#                                                  link
# 0   https://blog.naver.com/ha_tak?Redirect=Log&log...
# 1   https://blog.naver.com/busan_fish?Redirect=Log...
# 2   https://blog.naver.com/tearhunter?Redirect=Log...
# 3   https://blog.naver.com/artdodam?Redirect=Log&l...
# 4   https://blog.naver.com/doek11?Redirect=Log&log...
# ..                                                ...
# 95  https://blog.naver.com/had5400?Redirect=Log&lo...
# 96              https://blog.daum.net/tmddn1708/21681
# 97  https://blog.naver.com/hypoid613?Redirect=Log&...
# 98  https://blog.naver.com/gbajjang?Redirect=Log&l...
# 99  https://blog.naver.com/broom7tree?Redirect=Log...
#
# [1000 rows x 4 columns]

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1000 non-null   object
#  1   description  1000 non-null   object
#  2   postdate     1000 non-null   object
#  3   link         1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
# result_mol['lprice'] = result_mol['lprice'].astype('float')
# result_mol['hprice'] = result_mol['hprice'].astype('float')
# hprice 는 str임

# %%
writer = pd.ExcelWriter("./data/bllizard_in_naver_blog.xlsx",
                       engine='xlsxwriter')
result_mol.to_excel(writer,sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A',4)
worksheet.set_column('B:B',60)
worksheet.set_column('C:C',60)
worksheet.set_column('D:D',10)
worksheet.set_column('E:E',50)

worksheet.conditional_format('C2:C1001',{'type':'3_color_scale'})

writer.save()

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-1.3.7-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 275 kB/s eta 0:00:01
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.3.7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

# f_path = "/Library/Fonts/AppleGothic.ttf"
# font_name = font_manager.FontProperties(fname=f_path).get_name()
# rc('font',family=font_name)

# %%
plt.figure(figsize=(15,6))
sns.countplot('postdate',data=result_mol, palette="RdYlGn",
             order=result_mol['postdate'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
body = {
    "startDate" : "2017-01-01",
    "endDate" : "2017-04-30",
    "timeUnit" : "month",
    "keywordGroups" :[
        {"groupName" : "한글", "keywords":["한글","korean"]},
        {"groupName" : "영어", "keywords":["영어","english"]}
    ],
    "device":"pc",
    "ages":["1","2"],
    "gender":"f"
}

# %%
import json

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2017-01-01",
#     "endDate": "2017-04-30",
#     "timeUnit": "month",
#     "keywordGroups": [
#         {
#             "groupName": "한글",
#             "keywords": [
#                 "한글",
#                 "korean"
#             ]
#         },
#         {
#             "groupName": "영어",
#             "keywords": [
#                 "영어",
#                 "english"
#             ]
#         }
#     ],
#     "device": "pc",
#     "ages": [
#         "1",
#         "2"
#     ],
#     "gender": "f"
# }

# %%
url = "https://openapi.naver.com/v1/datalab/search"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode('utf-8'))

json.loads(response.read().decode('utf-8'))
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
def get_trend(body):
    url = "https://openapi.naver.com/v1/datalab/search"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode('utf-8'))
    
    return json.loads(response.read().decode('utf-8'))

# %%
get_trend(body)
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
body = {
    "startDate" : "2016-01-01",
    "endDate" : "2020-01-01",
    "timeUnit":"month",
    "keywordGroups" : [
        {
            "groupName" : "블리자드",
            "keywords" : ["디아블로","오버워치","하스스톤","스타크래프트"]
        },
    ]
}

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2016-01-01",
#     "endDate": "2020-01-01",
#     "timeUnit": "month",
#     "keywordGroups": [
#         {
#             "groupName": "블리자드",
#             "keywords": [
#                 "디아블로",
#                 "오버워치",
#                 "하스스톤",
#                 "스타크래프트"
#             ]
#         }
#     ]
# }

# %%
blizard_raw_data = get_trend(body)

# %%
blizard_raw_data
# Out:
# {'startDate': '2016-01-01',
#  'endDate': '2020-01-31',
#  'timeUnit': 'month',
#  'results': [{'title': '블리자드',
#    'keywords': ['디아블로', '오버워치', '하스스톤', '스타크래프트'],
#    'data': [{'period': '2016-01-01', 'ratio': 7.96108},
#     {'period': '2016-02-01', 'ratio': 57.55975},
#     {'period': '2016-03-01', 'ratio': 14.06109},
#     {'period': '2016-04-01', 'ratio': 28.63125},
#     {'period': '2016-05-01', 'ratio': 80.48382},
#     {'period': '2016-06-01', 'ratio': 100},
#     {'period': '2016-07-01', 'ratio': 79.33249},
#     {'period': '2016-08-01', 'ratio': 50.92924},
#     {'period': '2016-09-01', 'ratio': 56.62678},
#     {'period': '2016-10-01', 'ratio': 30.96556},
#     {'period': '2016-11-01', 'ratio': 36.41146},
#     {'period': '2016-12-01', 'ratio': 35.06865},
#     {'period': '2017-01-01', 'ratio': 29.9257},
#     {'period': '2017-02-01', 'ratio': 26.72852},
#     {'period': '2017-03-01', 'ratio': 42.77381},
#     {'period': '2017-04-01', 'ratio': 33.04927},
#     {'period': '2017-05-01', 'ratio': 28.86495},
#     {'period': '2017-06-01', 'ratio': 22.25636},
#     {'period': '2017-07-01', 'ratio': 25.93218},
#     {'period': '2017-08-01', 'ratio': 30.58986},
#     {'period': '2017-09-01', 'ratio': 23.35622},
#     {'period': '2017-10-01', 'ratio': 23.75053},
#     {'period': '2017-11-01', 'ratio': 25.5731},
#     {'period': '2017-12-01', 'ratio': 21.06395},
#     {'period': '2018-01-01', 'ratio': 21.1326},
#     {'period': '2018-02-01', 'ratio': 19.06258},
#     {'period': '2018-03-01', 'ratio': 17.67128},
#     {'period': '2018-04-01', 'ratio': 18.96626},
#     {'period': '2018-05-01', 'ratio': 18.3633},
#     {'period': '2018-06-01', 'ratio': 13.95058},
#     {'period': '2018-07-01', 'ratio': 17.27018},
#     {'period': '2018-08-01', 'ratio': 22.18907},
#     {'period': '2018-09-01', 'ratio': 18.51761},
#     {'period': '2018-10-01', 'ratio': 14.58432},
#     {'period': '2018-11-01', 'ratio': 15.57273},
#     {'period': '2018-12-01', 'ratio': 12.90206},
#     {'period': '2019-01-01', 'ratio': 12.46974},
#     {'period': '2019-02-01', 'ratio': 12.82719},
#     {'period': '2019-03-01', 'ratio': 11.20915},
#     {'period': '2019-04-01', 'ratio': 10.3037},
#     {'period': '2019-05-01', 'ratio': 10.35696},
#     {'period': '2019-06-01', 'ratio': 8.28596},
#     {'period': '2019-07-01', 'ratio': 9.30577},
#     {'period': '2019-08-01', 'ratio': 10.73484},
#     {'period': '2019-09-01', 'ratio': 9.86304},
#     {'period': '2019-10-01', 'ratio': 8.60296},
#     {'period': '2019-11-01', 'ratio': 10.15585},
#     {'period': '2019-12-01', 'ratio': 9.93703},
#     {'period': '2020-01-01', 'ratio': 9.26699}]}]}

# %%
blizard_raw_data['results'][0]['data']
# Out:
# [{'period': '2016-01-01', 'ratio': 7.96108},
#  {'period': '2016-02-01', 'ratio': 57.55975},
#  {'period': '2016-03-01', 'ratio': 14.06109},
#  {'period': '2016-04-01', 'ratio': 28.63125},
#  {'period': '2016-05-01', 'ratio': 80.48382},
#  {'period': '2016-06-01', 'ratio': 100},
#  {'period': '2016-07-01', 'ratio': 79.33249},
#  {'period': '2016-08-01', 'ratio': 50.92924},
#  {'period': '2016-09-01', 'ratio': 56.62678},
#  {'period': '2016-10-01', 'ratio': 30.96556},
#  {'period': '2016-11-01', 'ratio': 36.41146},
#  {'period': '2016-12-01', 'ratio': 35.06865},
#  {'period': '2017-01-01', 'ratio': 29.9257},
#  {'period': '2017-02-01', 'ratio': 26.72852},
#  {'period': '2017-03-01', 'ratio': 42.77381},
#  {'period': '2017-04-01', 'ratio': 33.04927},
#  {'period': '2017-05-01', 'ratio': 28.86495},
#  {'period': '2017-06-01', 'ratio': 22.25636},
#  {'period': '2017-07-01', 'ratio': 25.93218},
#  {'period': '2017-08-01', 'ratio': 30.58986},
#  {'period': '2017-09-01', 'ratio': 23.35622},
#  {'period': '2017-10-01', 'ratio': 23.75053},
#  {'period': '2017-11-01', 'ratio': 25.5731},
#  {'period': '2017-12-01', 'ratio': 21.06395},
#  {'period': '2018-01-01', 'ratio': 21.1326},
#  {'period': '2018-02-01', 'ratio': 19.06258},
#  {'period': '2018-03-01', 'ratio': 17.67128},
#  {'period': '2018-04-01', 'ratio': 18.96626},
#  {'period': '2018-05-01', 'ratio': 18.3633},
#  {'period': '2018-06-01', 'ratio': 13.95058},
#  {'period': '2018-07-01', 'ratio': 17.27018},
#  {'period': '2018-08-01', 'ratio': 22.18907},
#  {'period': '2018-09-01', 'ratio': 18.51761},
#  {'period': '2018-10-01', 'ratio': 14.58432},
#  {'period': '2018-11-01', 'ratio': 15.57273},
#  {'period': '2018-12-01', 'ratio': 12.90206},
#  {'period': '2019-01-01', 'ratio': 12.46974},
#  {'period': '2019-02-01', 'ratio': 12.82719},
#  {'period': '2019-03-01', 'ratio': 11.20915},
#  {'period': '2019-04-01', 'ratio': 10.3037},
#  {'period': '2019-05-01', 'ratio': 10.35696},
#  {'period': '2019-06-01', 'ratio': 8.28596},
#  {'period': '2019-07-01', 'ratio': 9.30577},
#  {'period': '2019-08-01', 'ratio': 10.73484},
#  {'period': '2019-09-01', 'ratio': 9.86304},
#  {'period': '2019-10-01', 'ratio': 8.60296},
#  {'period': '2019-11-01', 'ratio': 10.15585},
#  {'period': '2019-12-01', 'ratio': 9.93703},
#  {'period': '2020-01-01', 'ratio': 9.26699}]

# %%
ratio = [each['ratio'] for each in blizard_raw_data['results'][0]['data']]
ratio
# Out:
# [7.96108,
#  57.55975,
#  14.06109,
#  28.63125,
#  80.48382,
#  100,
#  79.33249,
#  50.92924,
#  56.62678,
#  30.96556,
#  36.41146,
#  35.06865,
#  29.9257,
#  26.72852,
#  42.77381,
#  33.04927,
#  28.86495,
#  22.25636,
#  25.93218,
#  30.58986,
#  23.35622,
#  23.75053,
#  25.5731,
#  21.06395,
#  21.1326,
#  19.06258,
#  17.67128,
#  18.96626,
#  18.3633,
#  13.95058,
#  17.27018,
#  22.18907,
#  18.51761,
#  14.58432,
#  15.57273,
#  12.90206,
#  12.46974,
#  12.82719,
#  11.20915,
#  10.3037,
#  10.35696,
#  8.28596,
#  9.30577,
#  10.73484,
#  9.86304,
#  8.60296,
#  10.15585,
#  9.93703,
#  9.26699]

# %%
data = [each['period'] for each in blizard_raw_data['results'][0]['data']]
data
# Out:
# ['2016-01-01',
#  '2016-02-01',
#  '2016-03-01',
#  '2016-04-01',
#  '2016-05-01',
#  '2016-06-01',
#  '2016-07-01',
#  '2016-08-01',
#  '2016-09-01',
#  '2016-10-01',
#  '2016-11-01',
#  '2016-12-01',
#  '2017-01-01',
#  '2017-02-01',
#  '2017-03-01',
#  '2017-04-01',
#  '2017-05-01',
#  '2017-06-01',
#  '2017-07-01',
#  '2017-08-01',
#  '2017-09-01',
#  '2017-10-01',
#  '2017-11-01',
#  '2017-12-01',
#  '2018-01-01',
#  '2018-02-01',
#  '2018-03-01',
#  '2018-04-01',
#  '2018-05-01',
#  '2018-06-01',
#  '2018-07-01',
#  '2018-08-01',
#  '2018-09-01',
#  '2018-10-01',
#  '2018-11-01',
#  '2018-12-01',
#  '2019-01-01',
#  '2019-02-01',
#  '2019-03-01',
#  '2019-04-01',
#  '2019-05-01',
#  '2019-06-01',
#  '2019-07-01',
#  '2019-08-01',
#  '2019-09-01',
#  '2019-10-01',
#  '2019-11-01',
#  '2019-12-01',
#  '2020-01-01']

# %%
plt.figure(figsize=(30,8))
plt.plot(data,ratio)

plt.xticks(rotation=90)
plt.show()

# %%
from datetime import date, timedelta

# x = pd.date_range('2018-01-01', '2019-04-30')
# x = pd.date_range(date(2018,1,1), periods=30, freq='D')
plt.figure(figsize=(18,6))
plt.plot(data,ratio)
# plt.grid()
plt.xticks(rotation=45)
plt.show()

# %%
blizard_pd = pd.DataFrame({'data':ratio}, index=data)
blizard_pd.head()
# Out:
#                 data
# 2016-01-01   7.96108
# 2016-02-01  57.55975
# 2016-03-01  14.06109
# 2016-04-01  28.63125
# 2016-05-01  80.48382

# %%
vertical_range = blizard_pd[blizard_pd['data']>40]
vertical_range
# Out:
#                  data
# 2016-02-01   57.55975
# 2016-05-01   80.48382
# 2016-06-01  100.00000
# 2016-07-01   79.33249
# 2016-08-01   50.92924
# 2016-09-01   56.62678
# 2017-03-01   42.77381

# %%
vertical_range.index[1],vertical_range.index[2],vertical_range.index[3]
# Out:
# ('2016-05-01', '2016-06-01', '2016-07-01')

# %%
vline = [vertical_range.index[0],
        vertical_range.index[2],
        vertical_range.index[3]]

# %%
plt.figure(figsize=(18,8))
plt.plot(data, ratio)

for each in vline:
    plt.axvline(x=each, color='black')
    
plt.grid()
plt.xticks('')
plt.show()

# %%
from random import randint

plt.figure(figsize=(18,8))
plt.plot(data, ratio)
for each in vline:
    plt.axvline(x=each, color='black')
    plt.annotate(each,xy=(each,randint(40,80)), size=15,
                arrowprops=dict(facecolor='black',shrink=0.04))

plt.xticks('')

plt.show()
