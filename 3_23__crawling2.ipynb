# %%
# !pip install bs4
# Out:
# ...
#      |████████████████████████████████| 115 kB 582 kB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=35b5aae4423cb2a00629448c2622b22b07b8d922fdc779922c1ad56777fa299f
#   Stored in directory: /Users/song-kang/Library/Caches/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = 'http://beans.itcarlow.ie/prices.html'
page = urlopen(url)
soup = BeautifulSoup(page,'html.parser')

# %%
print(soup.find('body'))
# Out:
# <body>
# <h2>Welcome to the Beans'R'Us Pricing Page</h2>
# <p>Current price of coffee beans = <strong>$5.14</strong></p>
# <p>Price valid for 15 minutes from Tue Mar 23 00:24:02 2021.</p>
# </body>

# %%
soup.find('strong').string
# Out:
# '$5.14'

# %%
soup.find('p').get_text() #get_text()ㄱㅏ 범위가 더 넓음
# Out:
# 'Current price of coffee beans = $5.14'

# %%
url = "https://book.naver.com/category/index.nhn?cate_code=280020"
page = urlopen(url)

soup = BeautifulSoup(page,"html.parser")

print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# TOP100, IT 전문서, 컴퓨터/IT : 네이버 책</title>
# <meta content="article" property="og:type"/>
# <meta content="네이버 책" property="og:title"/>
# <meta content="http://book.naver.com/category/index.nhn?cate_code=280020" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/m/book/icons/book_og_270x270.png" property="og:image"/>
# <meta content="책으로 만나는 새로운 세상" property="og:description"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버 책" property="og:article:author"/>
# <meta content="https://book.naver.com" property="og:article:author:url"/>
# <link href="https://www.naver.com/favicon.ico?book" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# var __bLogin = false;
# var __bAdult = false;
# </script>
# ...

# %%
soup.find_all(class_ = "N=a:bta.title")
# Out:
# [<a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=15431390">한국어 임베딩</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=15478327">Do it! 정직하게 코딩하며 배우는 딥러닝 입문</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=10835404">데이터 분석 전문가 가이드</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=6379151">SQL 전문가 가이드</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=15372757">리액트를 다루는 기술</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=15372183">나는 LINE 개발자입니다</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=15303798">클린 아키텍처</a>,
#  <a class="N=a:bta.title" href="http://book.naver.com/bookdb/book_detail.nhn?bid=14519321">한 권으로 끝내는 아두이노 입문 + 실전(종합편)</a>,
# ...

# %%
soup.find_all(class_ = "N=a:bta.title")[0]['href']
# Out:
# 'http://book.naver.com/bookdb/book_detail.nhn?bid=15431390'

# %%
soup.find_all(class_ = "N=a:bta.title")[0].string
# Out:
# '한국어 임베딩'

# %%
len(soup.find_all(class_ = "N=a:bta.title"))
# Out:
# 20

# %%
title = [i.string for i in soup.find_all(class_ = "N=a:bta.title")]
title
# Out:
# ['한국어 임베딩',
#  'Do it! 정직하게 코딩하며 배우는 딥러닝 입문',
#  '데이터 분석 전문가 가이드',
#  'SQL 전문가 가이드',
#  '리액트를 다루는 기술',
#  '나는 LINE 개발자입니다',
#  '클린 아키텍처',
#  '한 권으로 끝내는 아두이노 입문 + 실전(종합편)',
#  '다시 미분 적분',
#  '파이썬 날코딩으로 알고 짜는 딥러닝',
#  '소문난 명강의 김기현의 자연어 처리 딥러닝 캠프',
#  'Do it! 점프 투 파이썬',
#  '오브젝트',
#  '혼자 공부하는 파이썬',
#  '혼자 공부하는 C 언어',
#  '혼자 공부하는 자바',
#  '머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로',
#  '파이썬 라이브러리를 활용한 데이터 분석',
#  '알고리즘 트레이닝',
#  '밑바닥부터 시작하는 딥러닝 2']

# %%
soup.find_all(class_ = "txt_desc")
# Out:
# [<dd class="txt_desc">
#  <div class="review_point">
#  <span style="width:100%;"></span>
#  </div>
#  								10.0<span class="bar"> | </span>
#  <a class="N=a:bta.review" href="http://book.naver.com/bookdb/review.nhn?bid=15431390">네티즌리뷰 1건</a>
#  <span class="bar">|</span>
#  <a class="N=a:bta.bookbuy" href="javascript:showBuyLayerByBid('15431390')" id="buy_btn_15431390" onclick="return showAdultLayer('15431390', 'false', 'false', 'false');"><img alt="도서구매" class="btn v2" height="20" id="btn_buy_15431390" src="https://ssl.pstatic.net/static/book/image/btn_book_buy.gif" title="구매 가능한 도서입니다." width="48"/></a>
#  <strike>35,000원</strike> → <em class="price">31,500원(-10%)</em>
#  <!--  ebook 가격 정보 -->
# ...

# %%
soup.find('dd','txt_desc').get_text()
# Out:
# '\n\n\n\r\n\t\t\t\t\t\t\t\t10.0 | \n네티즌리뷰 1건\n|\n\n35,000원 → 31,500원(-10%)\n\n25,200원\r\n\t\t\t\t\t\t\t\t\t\t\t\n'

# %%
import re
tmp = soup.find('dd','txt_desc').get_text()
result = re.search("\d+.\d+",tmp)

'''
group이 위의 "\d+.\d+" 패턴을 찾아서 글자로 바꿔주는 기능을 함
'''
if result:
    print(result.group())
# Out:
# 10.0

# %%
score = []

for i in soup.find_all('dd','txt_desc'):
    result = re.search("\d+.(\d+)?", i.get_text())
    
    score.append(result.group())
score
# Out:
# ['10.0',
#  '10.0',
#  '0.0',
#  '7.5',
#  '0.0',
#  '9.5',
#  '0.0',
#  '0.0',
#  '9.0',
#  '10.0',
#  '0.0',
#  '10.0',
#  '0.0',
#  '9.0',
#  '0.0',
#  '10.0',
#  '10.0',
#  '0.0',
#  '10.0',
#  '9.329999923706055']

# %%
soup.find('dd','txt_block').get_text()
# Out:
# '\n 이기창 저 |\n에이콘출판 | 2019.09.26'

# %%
tmp = soup.find('dd','txt_block').get_text()

result = re.search("\d+.\d+.\d+",tmp)

if result:
    print(result.group())
# Out:
# 2019.09.26

# %%
date = []

for i in soup.find_all('dd','txt_block'):
    result = re.search('\d+.\d+.\d+',i.get_text())
    
    date.append(result.group())
    
date
# Out:
# ['2019.09.26',
#  '2019.09.20',
#  '2019.09.06',
#  '2019.09.06',
#  '2019.08.31',
#  '2019.08.23',
#  '2019.08.20',
#  '2019.08.15',
#  '2019.07.31',
#  '2019.07.15',
#  '2019.07.01',
#  '2019.06.20',
#  '2019.06.17',
#  '2019.06.10',
#  '2019.06.10',
#  '2019.06.10',
#  '2019.05.24',
#  '2019.05.20',
#  '2019.05.09',
#  '2019.05.01']

# %%
import pandas as pd
bestseller = pd.DataFrame({
    '책재목' : title,
    '평점' : score,
    '출판일' : date
},index=range(1,21))

bestseller
# Out:
#                                책재목                 평점         출판일
# 1                          한국어 임베딩               10.0  2019.09.26
# 2      Do it! 정직하게 코딩하며 배우는 딥러닝 입문               10.0  2019.09.20
# 3                   데이터 분석 전문가 가이드                0.0  2019.09.06
# 4                      SQL 전문가 가이드                7.5  2019.09.06
# 5                      리액트를 다루는 기술                0.0  2019.08.31
# 6                   나는 LINE 개발자입니다                9.5  2019.08.23
# 7                          클린 아키텍처                0.0  2019.08.20
# 8      한 권으로 끝내는 아두이노 입문 + 실전(종합편)                0.0  2019.08.15
# 9                         다시 미분 적분                9.0  2019.07.31
# 10             파이썬 날코딩으로 알고 짜는 딥러닝               10.0  2019.07.15
# 11      소문난 명강의 김기현의 자연어 처리 딥러닝 캠프                0.0  2019.07.01
# 12                 Do it! 점프 투 파이썬               10.0  2019.06.20
# 13                            오브젝트                0.0  2019.06.17
# ...

# %%
bestseller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 1 to 20
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   책재목     20 non-null     object
#  1   평점      20 non-null     object
#  2   출판일     20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes

# %%
pd.options.display.float_format = '{:.2f}'.format
bestseller['평점'] = bestseller['평점'].astype(float)
bestseller
# Out:
#                                책재목    평점         출판일
# 1                          한국어 임베딩 10.00  2019.09.26
# 2      Do it! 정직하게 코딩하며 배우는 딥러닝 입문 10.00  2019.09.20
# 3                   데이터 분석 전문가 가이드  0.00  2019.09.06
# 4                      SQL 전문가 가이드  7.50  2019.09.06
# 5                      리액트를 다루는 기술  0.00  2019.08.31
# 6                   나는 LINE 개발자입니다  9.50  2019.08.23
# 7                          클린 아키텍처  0.00  2019.08.20
# 8      한 권으로 끝내는 아두이노 입문 + 실전(종합편)  0.00  2019.08.15
# 9                         다시 미분 적분  9.00  2019.07.31
# 10             파이썬 날코딩으로 알고 짜는 딥러닝 10.00  2019.07.15
# 11      소문난 명강의 김기현의 자연어 처리 딥러닝 캠프  0.00  2019.07.01
# 12                 Do it! 점프 투 파이썬 10.00  2019.06.20
# 13                            오브젝트  0.00  2019.06.17
# 14                     혼자 공부하는 파이썬  9.00  2019.06.10
# 15                    혼자 공부하는 C 언어  0.00  2019.06.10
# 16                      혼자 공부하는 자바 10.00  2019.06.10
# 17  머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로 10.00  2019.05.24
# ...

# %%
url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cnt&tg=0&date=20210321"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cnt&amp;tg=0&amp;date=20210321" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit3')
# Out:
# [<div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=187310" title="미나리">미나리</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=196051" title="극장판 귀멸의 칼날: 무한열차편">극장판 귀멸의 칼날: 무한열차편</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=184518" title="라야와 마지막 드래곤">라야와 마지막 드래곤</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=203288" title="잭 스나이더의 저스티스 리그">잭 스나이더의 저스티스 리그</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=193800" title="모리타니안">모리타니안</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=189124" title="미션 파서블">미션 파서블</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=182019" title="리스타트">리스타트</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=184517" title="소울">소울</a>
#  </div>,
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=17059" title="중경삼림">중경삼림</a>
#  </div>,
# ...

# %%
soup.find_all('div','tit3')[0].a
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=187310" title="미나리">미나리</a>

# %%
soup.find_all('div','tit3')[0].a.string
# Out:
# '미나리'

# %%
movie_name = [i.a.string for i in soup.find_all('div','tit3')]
movie_name
# Out:
# ['미나리',
#  '극장판 귀멸의 칼날: 무한열차편',
#  '라야와 마지막 드래곤',
#  '잭 스나이더의 저스티스 리그',
#  '모리타니안',
#  '미션 파서블',
#  '리스타트',
#  '소울',
#  '중경삼림',
#  '반지의 제왕: 두 개의 탑',
#  '정말 먼 곳',
#  '아수라도',
#  '고질라 VS. 콩',
#  '저스티스 리그',
#  '아이 씨 유',
#  '반지의 제왕: 반지 원정대',
#  '반지의 제왕: 왕의 귀환',
#  '최면',
#  '스파이의 아내',
#  '웨이 다운',
#  '파이터',
#  '빛과 철',
#  '허트 로커',
#  '자산어보',
#  '그녀가 사라졌다',
#  '카오스 워킹',
#  '인천스텔라',
#  '몬테크리스토: 더 뮤지컬 라이브',
#  '러빙 빈센트',
#  '포제서',
#  '실종: 사라진 사람들',
#  '암모나이트',
#  '고백',
#  '톰과 제리',
#  '더 박스',
#  '아무도 없는 곳',
#  '브레이브 언더 파이어',
#  '더 레이서',
#  '유어 아이즈 텔',
#  '아이',
#  '모탈 컴뱃',
#  '태극기 휘날리며',
#  '마리오네트',
#  '랜드',
#  '노매드랜드',
#  '어른들은 몰라요',
#  '은지: 돌이킬 수 없는 그녀',
#  '퍼펙트 케어',
#  '2046',
#  '300: 전사의 귀환']

# %%
soup.find_all('td')
# Out:
# [<td class="blank01" colspan="8"></td>,
#  <td class="ac"><img alt="01" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r01.gif" width="14"/></td>,
#  <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=187310" title="미나리">미나리</a>
#  </div>
#  </td>,
#  <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>,
#  <td class="range ac">0</td>,
#  <td class="ac"><img alt="02" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r02.gif" width="14"/></td>,
#  <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.nhn?code=196051" title="극장판 귀멸의 칼날: 무한열차편">극장판 귀멸의 칼날: 무한열차편</a>
#  </div>
#  </td>,
#  <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>,
#  <td class="range ac">0</td>,
# ...

# %%
url2 = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20210322"
page2 = urlopen(url2)

soup2 = BeautifulSoup(page2, "html.parser")
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20210322" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup2.find_all('td','point')
# Out:
# [<td class="point">9.49</td>,
#  <td class="point">9.38</td>,
#  <td class="point">9.37</td>,
#  <td class="point">9.36</td>,
#  <td class="point">9.34</td>,
#  <td class="point">9.31</td>,
#  <td class="point">9.31</td>,
#  <td class="point">9.29</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.20</td>,
#  <td class="point">9.14</td>,
#  <td class="point">9.12</td>,
#  <td class="point">9.09</td>,
#  <td class="point">9.06</td>,
#  <td class="point">8.97</td>,
#  <td class="point">8.94</td>,
#  <td class="point">8.93</td>,
#  <td class="point">8.92</td>,
#  <td class="point">8.82</td>,
#  <td class="point">8.79</td>,
#  <td class="point">8.79</td>,
#  <td class="point">8.79</td>,
#  <td class="point">8.78</td>,
#  <td class="point">8.76</td>,
#  <td class="point">8.74</td>,
#  <td class="point">8.71</td>,
#  <td class="point">8.56</td>,
#  <td class="point">8.55</td>,
#  <td class="point">8.52</td>,
# ...

# %%
soup2.find_all('td','point')[0].string
# Out:
# '9.49'

# %%
movie_point = [i.string for i in soup2.find_all('td','point')]
movie_point
# Out:
# ['9.49',
#  '9.38',
#  '9.37',
#  '9.36',
#  '9.34',
#  '9.31',
#  '9.31',
#  '9.29',
#  '9.28',
#  '9.22',
#  '9.22',
#  '9.20',
#  '9.14',
#  '9.12',
#  '9.09',
#  '9.06',
#  '8.97',
#  '8.94',
#  '8.93',
#  '8.92',
#  '8.82',
#  '8.79',
#  '8.79',
#  '8.79',
#  '8.78',
#  '8.76',
#  '8.74',
#  '8.71',
#  '8.56',
#  '8.55',
#  '8.52',
#  '8.51',
#  '8.48',
#  '8.43',
#  '8.26',
#  '8.19',
#  '8.13',
#  '8.11',
#  '8.03',
#  '7.96',
#  '7.84',
#  '7.79',
#  '7.77',
#  '7.64',
#  '7.38',
#  '7.20',
#  '6.72',
#  '6.55',
#  '6.43',
#  '6.29']

# %%
date = pd.date_range('2021.03.01',periods=20, freq='D')
date
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#                '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12',
#                '2021-03-13', '2021-03-14', '2021-03-15', '2021-03-16',
#                '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
date[0]
# Out:
# Timestamp('2021-03-01 00:00:00', freq='D')

# %%
print(date[0].strftime('%y-%m-%d'))
print(date[0].strftime('%y.%m.%d'))
# Out:
# 21-03-01
# 21.03.01

# %%
date[0].strftime('%Y%m%d') # %Y로 하면 연도를 네자리로 받아옴
# Out:
# '20210301'

# %%
import time

movie_date = []
movie_name = []
movie_point = []

# %%
for today in date:
    html = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}'
    response = urlopen(html.format(date = today.strftime("%Y%m%d")))
    soup = BeautifulSoup(response,"html.parser")
    
    movie_date.extend([today]*len(soup.find_all('td','point')))
    movie_name.extend([each.a.string for each in soup.find_all('div','tit5')])
    movie_point.extend([each.string for each in soup.find_all('td','point')])
    
print(str(today))
time.sleep(0.5)
# Out:
# 2021-03-20 00:00:00

# %%
len(movie_date),len(movie_name),len(movie_point)
# Out:
# (997, 997, 997)

# %%
movie = pd.DataFrame({
    'date' : movie_date,
    'name' : movie_name,
    'point' : movie_point
})
movie
# Out:
#           date                    name point
# 0   2021-03-01  디지몬 어드벤처 라스트 에볼루션 : 인연  9.56
# 1   2021-03-01                      원더  9.51
# 2   2021-03-01           극장판 바이올렛 에버가든  9.50
# 3   2021-03-01               송가인 더 드라마  9.43
# 4   2021-03-01            서유기 2 - 선리기연  9.36
# ..         ...                     ...   ...
# 992 2021-03-20                     미나리  7.87
# 993 2021-03-20                    철벽선생  7.77
# 994 2021-03-20                   톰과 제리  7.63
# 995 2021-03-20                  미션 파서블  7.40
# 996 2021-03-20                      은혼  7.20
#
# [997 rows x 3 columns]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    997 non-null    datetime64[ns]
#  1   name    997 non-null    object
#  2   point   997 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 23.5+ KB

# %%
movie['point'] = movie['point'].astype('float')

# %%
movie.to_csv('./data/04_naver_movie_raw_data.csv',sep=",", encoding='utf-8')

# %%
movie = pd.read_csv('./data/04_naver_movie_raw_data.csv', index_col=0)
movie
# Out:
#            date                    name  point
# 0    2021-03-01  디지몬 어드벤처 라스트 에볼루션 : 인연   9.56
# 1    2021-03-01                      원더   9.51
# 2    2021-03-01           극장판 바이올렛 에버가든   9.50
# 3    2021-03-01               송가인 더 드라마   9.43
# 4    2021-03-01            서유기 2 - 선리기연   9.36
# ..          ...                     ...    ...
# 992  2021-03-20                     미나리   7.87
# 993  2021-03-20                    철벽선생   7.77
# 994  2021-03-20                   톰과 제리   7.63
# 995  2021-03-20                  미션 파서블   7.40
# 996  2021-03-20                      은혼   7.20
#
# [997 rows x 3 columns]

# %%
movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_unique
# Out:
#                    point
# name
# 국가부도의 날            16.26
# 그녀                136.48
# 그레이트 뷰티            55.51
# 극장판 귀멸의 칼날: 무한열차편 185.55
# 극장판 바이올렛 에버가든     189.89
# ...                  ...
# 해리 포터와 불의 잔       160.60
# 해피 투게더            184.04
# 허트 로커              84.30
# 현기증                52.32
# 화양연화              175.76
#
# [83 rows x 1 columns]

# %%
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best
# Out:
#                    point
# name
# 극장판 바이올렛 에버가든     189.89
# 서유기 2 - 선리기연      187.20
# 부활: 그 증거          186.80
# 소울                186.19
# 극장판 귀멸의 칼날: 무한열차편 185.55
# ...                  ...
# 국가부도의 날            16.26
# 더 울프 오브 월 스트리트     16.10
# 어니스트 씨프            15.54
# 열혈남아               15.44
# 더 프롬               14.54
#
# [83 rows x 1 columns]

# %%
movie.query('name ==["열혈남아"]')
#query로 영화제목 검색 가능
# Out:
#            date  name  point
# 791  2021-03-16  열혈남아   7.72
# 841  2021-03-17  열혈남아   7.72

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.plot(movie.query('name == ["소울"]')['date'],
        movie.query('name == ["소울"]')['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
movie_pivot = pd.pivot_table(movie,index=['date'],columns=['name'])
movie_pivot.columns = movie_pivot.columns.droplevel([0])
movie_pivot
# Out:
# name        국가부도의 날   그녀  그레이트 뷰티  극장판 귀멸의 칼날: 무한열차편  극장판 바이올렛 에버가든  \
# date
# 2021-03-01      NaN  NaN     7.93               9.25           9.50
# 2021-03-02      NaN  NaN     7.93               9.25           9.50
# 2021-03-03      NaN  NaN     7.93               9.25           9.50
# 2021-03-04      NaN  NaN     7.93               9.25           9.50
# 2021-03-05      NaN 8.53     7.93               9.25           9.50
# 2021-03-06      NaN 8.53     7.93               9.26           9.50
# 2021-03-07      NaN 8.53     7.93               9.27           9.50
# 2021-03-08      NaN 8.53      NaN               9.27           9.50
# 2021-03-09      NaN 8.53      NaN               9.27           9.50
# 2021-03-10      NaN 8.53      NaN               9.28           9.49
# 2021-03-11      NaN 8.53      NaN               9.28           9.49
# 2021-03-12      NaN 8.53      NaN               9.29           9.49
# 2021-03-13      NaN 8.53      NaN               9.29           9.49
# ...

# %%
movie_pivot.to_excel("./data/04_movie_pivot.xlsx")

# %%
movie_pivot.columns
# Out:
# Index(['국가부도의 날', '그녀', '그레이트 뷰티', '극장판 귀멸의 칼날: 무한열차편', '극장판 바이올렛 에버가든',
#        '극장판 소드 아트 온라인 -오디널 스케일-', '극장판 쿠로코의 농구 라스트 게임', '나, 다니엘 블레이크',
#        '나는 내일, 어제의 너와 만난다', '날씨의 아이', '남매의 여름밤', '너의 이름은.', '달라스 바이어스 클럽',
#        '당신, 거기 있어줄래요', '더 울프 오브 월 스트리트', '더 포스트', '더 프롬', '더 헌트', '더블패티', '동주',
#        '디지몬 어드벤처 라스트 에볼루션 : 인연', '똥파리', '라야와 마지막 드래곤', '람보-특별판',
#        '러브 라이브! 더 스쿨 아이돌 무비', '러브 액츄얼리', '러브레터', '러빙 빈센트', '몬스터 헌터', '무드 인디고',
#        '뮨: 달의 요정', '미나리', '미션 파서블', '반지의 제왕: 두 개의 탑', '반지의 제왕: 반지 원정대',
#        '반지의 제왕: 왕의 귀환', '별을 쫓는 아이', '부활: 그 증거', '분노', '불한당: 나쁜 놈들의 세상',
#        '비포 미드나잇', '빅쇼트', '새해전야', '서유기 - 월광보합', '서유기 2 - 선리기연', '세자매', '소공녀',
#        '소울', '송가인 더 드라마', '싸이코', '쏘아올린 불꽃, 밑에서 볼까? 옆에서 볼까?', '아메리칸 허슬', '아비정전',
#        '아이', '아티스트', '어니스트 씨프', '열혈남아', '엽기적인 그녀', '온워드: 단 하루의 기적', '원더',
#        '원챈스', '은혼', '일대종사', '제로 다크 서티', '중경삼림', '찬실이는 복도 많지', '철벽선생', '카오스 워킹',
# ...

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
rc('font',family='AppleGothic')


import seaborn as sns

# f_path = '/User/song-kang/Library/Fonts/AppleGothic.ttf'
# font_name = font_manager.FontProperties(fname=f_path).get_name()

# %%
target_col = ['국가부도의 날', '그녀', '그레이트 뷰티', '극장판 귀멸의 칼날: 무한열차편', '극장판 바이올렛 에버가든',
       '극장판 소드 아트 온라인 -오디널 스케일-', '극장판 쿠로코의 농구 라스트 게임']
plt.figure(figsize=(12,8))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc="best")
plt.tick_params(bottom=False, labelbottom=False)
plt.show()
