# %%
# client ID : "NBIdLcJq6KfcFvAXcdRx"
# client Secret : "CBPAWvsX12"

# %%
import urllib.request

client_id ="NBIdLcJq6KfcFvAXcdRx"
client_secret = "CBPAWvsX12"
encText = urllib.parse.quote("파이썬")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
response.getcode()
# Out:
# 200

# %%
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Mon, 22 Mar 2021 17:58:28 +0900",
# "total": 223715,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 학원 관리가 필요한 이유!",
# "link": "https:\/\/blog.naver.com\/blueskyjoo7?Redirect=Log&logNo=222247271856",
# "description": "<b>파이썬</b> 학원 관리가 필요한 이유! 아이티라는 업종에 관심이 생기기 시작하면서 본격적으로 이와... 그래서 저는 몇 군데의 <b>파이썬</b> 학원을 돌아 다녀봤는데요. 여러 기관을 둘러봤었는데 가장 꼼꼼하게... ",
# "bloggername": "붉은별의 블로그",
# "bloggerlink": "https://blog.naver.com/blueskyjoo7",
# "postdate": "20210217"
#
# },
# {
# "title": "부산<b>파이썬</b>학원 미련없는 선정방법!",
# "link": "https:\/\/blog.naver.com\/zhoongumo?Redirect=Log&logNo=222170922939",
# "description": "그래서 복습을 할 겸 다시 배워볼까 해서 부산<b>파이썬</b>학원을 찾아보았어요. 제가 자신 있게 말하건대... 부산<b>파이썬</b>학원의 빅데이터 사이언스 과정은 정규과정으로 총 교육 기간은 2개월이에요. 너무 길지도... ",
# "bloggername": "중국유학 성공예감",
# "bloggerlink": "https://blog.naver.com/zhoongumo",
# "postdate": "20201212"
#
# },
# {
# "title": "<b>파이썬</b> 설치는 초보자에게 아나콘다가 편합니다.",
# "link": "https:\/\/blog.naver.com\/ocmarketing?Redirect=Log&logNo=222197056590",
# "description": "안녕하세요, 오늘 부터는 <b>파이썬</b> 강의를 하나씩 해보려고 합니다. 일단 저도 배우는 입장이라... 그래서 첫번째 시간에 <b>파이썬</b> 설치를 하려고 하는데요, 어라? <b>파이썬</b>에 가서 바로 설치를 하는 것이... ",
# "bloggername": "초튜터 X 오씨네학교",
# "bloggerlink": "https://blog.naver.com/ocmarketing",
# "postdate": "20210105"
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 국비지원 받고 취업 성공한 후기!",
# "link": "https:\/\/blog.naver.com\/blueyo007?Redirect=Log&logNo=222250515678",
# "description": "오늘은 <b>파이썬</b> 머신러닝을 국비지원으로 진행해 취업에 성공한 이O선 이라고 합니다! 4차산업시대인... 자바, <b>파이썬</b> 머신러닝 과정으로 두개의 프로그래밍언어를 연계한 머신러닝 활용 개발자... ",
# "bloggername": "무쓸모 일기장",
# "bloggerlink": "https://blog.naver.com/blueyo007",
# "postdate": "20210220"
#
# },
# {
# "title": "인기강좌 <b>파이썬</b>을 집에서 - mos 학원 [에듀얍]",
# "link": "https:\/\/blog.naver.com\/v_heyo_v?Redirect=Log&logNo=222267148212",
# "description": "컴퓨터 잘 모르시는 분들도 한번쯤 들어보셨을 [<b>파이썬</b>] 요즘 워낙 핫 하잖아요. 재테크 하시는 분들에게도 필수가 되어버린 컴퓨터언어 [ <b>파이썬</b> ] 인기 강사들의 강의를 들으려니 20만원 가까이 하는... ",
# "bloggername": "영재교육선생님과 아이들",
# "bloggerlink": "https://blog.naver.com/v_heyo_v",
# "postdate": "20210307"
#
# },
# {
# "title": "몹시 어려운 <b>파이썬</b> ㅠㅠ",
# "link": "https:\/\/blog.naver.com\/twophase?Redirect=Log&logNo=222250340442",
# "description": "올해 이루고자 하는 개인적인 목표 중 하나는, &quot;<b>파이썬</b>을 씹어 먹겠다&quot; 이다. 영원히 지속가능한 프로그래밍 언어는 없겠지만, 지금까지 살면서 <b>파이썬</b> 만큼 광범위하게 돌풍을 일으키는 언어는 없었던 것 같다.... ",
# "bloggername": "새다리 종합 기록실 (일상속 연구노트)",
# "bloggerlink": "https://blog.naver.com/twophase",
# "postdate": "20210220"
#
# },
# {
# "title": "<b>파이썬</b>인강 처음이라면 어렵지 않게",
# "link": "https:\/\/blog.naver.com\/hecouple?Redirect=Log&logNo=222221577029",
# "description": "<b>파이썬</b>인강 처음이라면 어렵지 않게 안녕하세요. 현대사회에서는 없어서는 안 될 필수 전자기기라고... 있는 <b>파이썬</b>인강에 대해 알아보는 시간을 가져보겠습니다. 4차산업이 활발해짐에 따라 가장 활발해진... ",
# "bloggername": "[토폴라]",
# "bloggerlink": "https://blog.naver.com/hecouple",
# "postdate": "20210127"
#
# },
# {
# "title": "Introduction to <b>파이썬</b>(황재호)",
# "link": "https:\/\/blog.naver.com\/xnosis01?Redirect=Log&logNo=222244418309",
# "description": "Introduction to <b>파이썬</b> 작가 황재호 출판 인포앤북 발매 2021.03.01. 리뷰보기 많은 <b>파이썬</b> 책들이 출간되어 있습니다. 초급과정도 있고 중급과 고급도 있을 겁니다. &lt;Introduction to <b>파이썬</b>&gt;은 기초수준문법에 중요한... ",
# "bloggername": "전시회다이어리",
# "bloggerlink": "https://blog.naver.com/xnosis01",
# "postdate": "20210215"
#
# },
# {
# "title": "프로그래밍기초 책 (Doit첫코딩 With <b>파이썬</b>)",
# "link": "https:\/\/blog.naver.com\/thwnd20?Redirect=Log&logNo=222224502574",
# "description": "<b>파이썬</b>, C언어, 자바, 웹사이트용 HTML&amp;CSS 등 여러 언어들이 있는데요. 저는 그 중 난이도가 낮은 <b>파이썬</b>을 공부해보기로 했어요. <b>파이썬</b>은 문법이 간단해 입문자들이 배우기 쉬운 언어라고 해요. 오늘은... ",
# "bloggername": "까만눈",
# "bloggerlink": "https://blog.naver.com/thwnd20",
# "postdate": "20210129"
#
# },
# {
# "title": "코딩배우기 <b>파이썬</b>이라면 도전해 볼 만해요!",
# "link": "https:\/\/blog.naver.com\/smujack?Redirect=Log&logNo=222253634096",
# "description": "낮은 <b>파이썬</b>을 추천해드리고 싶어요. 유유가 대학교 때 문과를 전공하다가 살면서 처음으로 이과에 도전해봤는데, 공대 수업 중에서 가장 쉽고 또 재미있던 언어가 <b>파이썬</b>이었어요. 그때 배웠던 언어 잊고... ",
# "bloggername": "유유의 이야기 한 잔",
# "bloggerlink": "https://blog.naver.com/smujack",
# "postdate": "20210223"
#
# }
# ]
# }

# %%
def gen_search_

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
import json
import datetime
def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    response = urllib.request.urlopen(request)
    
    print('[%s] url request success' %datetime.datetime.now())
    
    return json.loads(response.read().decode('utf-8'))

# %%
client_id ="NBIdLcJq6KfcFvAXcdRx"
client_secret = "CBPAWvsX12"

url = gen_search_url('shop','몰스킨',1,5)
one_result = get_result_onpage(url)
# Out:
# [2021-03-22 20:22:29.433097] url request success

# %%
one_result
# Out:
# {'lastBuildDate': 'Mon, 22 Mar 2021 20:11:55 +0900',
#  'total': 26674,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '몰스킨 2021 다이어리 데일리 위클리 포켓 고급 명품 스타벅스 감성 휴대용 여자 각인',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82635708485',
#    'image': 'https://shopping-phinf.pstatic.net/main_8263570/82635708485.2.jpg',
#    'lprice': '24100',
#    'hprice': '',
#    'mallName': '에코펜',
#    'productId': '82635708485',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '몰스킨 2021 위클리 소프트 P-',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=25430082807',
#    'image': 'https://shopping-phinf.pstatic.net/main_2543008/25430082807.20201230215155.jpg',
#    'lprice': '13400',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '25430082807',
#    'productType': '1',
#    'brand': '',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '스타벅스 다이어리 2021 몰스킨 다이어리 플래너 폴더블 크로스백',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82734408367',
#    'image': 'https://shopping-phinf.pstatic.net/main_8273440/82734408367.1.jpg',
#    'lprice': '9000',
#    'hprice': '',
#    'mallName': '파이영',
#    'productId': '82734408367',
#    'productType': '2',
#    'brand': '스타벅스',
#    'maker': '스타벅스',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24014924801',
#    'image': 'https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg',
#    'lprice': '18570',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24014924801',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '몰스킨 2021위클리 가로형 소프트 L',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=25133204000',
#    'image': 'https://shopping-phinf.pstatic.net/main_2513320/25133204000.20201207204219.jpg',
#    'lprice': '8800',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '25133204000',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'}]}

# %%
for i in one_result['items']:
    i['title'] = i['title'].replace('<b>','')
    i['title'] = i['title'].replace('</b>','')
    print(i['title'])
# Out:
# 몰스킨 2021 다이어리 데일리 위클리 포켓 고급 명품 스타벅스 감성 휴대용 여자 각인
# 몰스킨 2021 위클리 소프트 P-
# 스타벅스 다이어리 2021 몰스킨 다이어리 플래너 폴더블 크로스백
# 몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린
# 몰스킨 2021위클리 가로형 소프트 L

# %%
import pandas as pd

def get_fields(json_data):
    title = [each['title'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'link' : link,
        'lprice' : lprice,
        'hprice' : hprice,
        'mall' : mall_name
    },
    columns=['title','link','lprice','hprice','mall'])
    
    return result_pd

# %%
one_result
# Out:
# {'lastBuildDate': 'Mon, 22 Mar 2021 20:22:29 +0900',
#  'total': 26670,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '<b>몰스킨</b> 2021 다이어리 데일리 위클리 포켓 고급 명품 스타벅스 감성 휴대용 여자 각인',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82635708485',
#    'image': 'https://shopping-phinf.pstatic.net/main_8263570/82635708485.2.jpg',
#    'lprice': '24100',
#    'hprice': '',
#    'mallName': '에코펜',
#    'productId': '82635708485',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 2021 위클리 소프트 P-',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=25430082807',
#    'image': 'https://shopping-phinf.pstatic.net/main_2543008/25430082807.20201230215155.jpg',
#    'lprice': '13400',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '25430082807',
#    'productType': '1',
#    'brand': '',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '스타벅스 다이어리 2021 <b>몰스킨</b> 다이어리 플래너 폴더블 크로스백',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82734408367',
#    'image': 'https://shopping-phinf.pstatic.net/main_8273440/82734408367.1.jpg',
#    'lprice': '9000',
#    'hprice': '',
#    'mallName': '파이영',
#    'productId': '82734408367',
#    'productType': '2',
#    'brand': '스타벅스',
#    'maker': '스타벅스',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24014924801',
#    'image': 'https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg',
#    'lprice': '18570',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24014924801',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '<b>몰스킨</b> 2021위클리 가로형 소프트 L',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=25133204000',
#    'image': 'https://shopping-phinf.pstatic.net/main_2513320/25133204000.20201207204219.jpg',
#    'lprice': '8800',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '25133204000',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'}]}

# %%
get_fields(one_result)
# Out:
#                                               title  \
# 0  몰스킨 2021 다이어리 데일리 위클리 포켓 고급 명품 스타벅스 감성 휴대용 여자 각인
# 1                               몰스킨 2021 위클리 소프트 P-
# 2              스타벅스 다이어리 2021 몰스킨 다이어리 플래너 폴더블 크로스백
# 3                       몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린
# 4                             몰스킨 2021위클리 가로형 소프트 L
#
#                                                 link lprice hprice mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  24100         에코펜
# 1  https://search.shopping.naver.com/gate.nhn?id=...  13400         네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   9000         파이영
# 3  https://search.shopping.naver.com/gate.nhn?id=...  18570         네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...   8800         네이버

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>','')
    input_str = input_str.replace('</b>','')
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'link' : link,
        'lprice' : lprice,
        'hprice' : hprice,
        'mall' : mall_name
    },
    columns=['title','link','lprice','hprice','mall'])
    
    return result_pd

# %%
result_mol = []

for i in range(1,1000,100):
    url = gen_search_url('shop','몰스킨',i,100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
# Out:
# [2021-03-22 20:25:33.041132] url request success
# [2021-03-22 20:25:33.276819] url request success
# [2021-03-22 20:25:33.519225] url request success
# [2021-03-22 20:25:33.749745] url request success
# [2021-03-22 20:25:33.997807] url request success
# [2021-03-22 20:25:34.249811] url request success
# [2021-03-22 20:25:34.778225] url request success
# [2021-03-22 20:25:35.010396] url request success
# [2021-03-22 20:25:35.248391] url request success
# [2021-03-22 20:25:35.548269] url request success

# %%
result_mol = pd.concat(result_mol)

# %%
result_mol
# Out:
#                                                title  \
# 0   몰스킨 2021 다이어리 데일리 위클리 포켓 고급 명품 스타벅스 감성 휴대용 여자 각인
# 1                                몰스킨 2021 위클리 소프트 P-
# 2               스타벅스 다이어리 2021 몰스킨 다이어리 플래너 폴더블 크로스백
# 3                        몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린
# 4                              몰스킨 2021위클리 가로형 소프트 L
# ..                                               ...
# 95                                   몰스킨 까이에 엑스라지 낱권
# 96       [핫트랙스] 몰스킨 몰스킨 T 클래식 매치 - 라운드탑 스몰 백팩/우드 브라운
# 97                                몰스킨 멀티 케이스 (LARGE)
# 98       (잉글랜드)Moleskine Journey Extra 스몰 Pouch Hard
# 99                                       몰스킨 백팩 - 스몰
#
#                                                  link  lprice hprice    mall
# 0   https://search.shopping.naver.com/gate.nhn?id=...   24100            에코펜
# 1   https://search.shopping.naver.com/gate.nhn?id=...   13400            네이버
# 2   https://search.shopping.naver.com/gate.nhn?id=...    9000            파이영
# 3   https://search.shopping.naver.com/gate.nhn?id=...   18570            네이버
# 4   https://search.shopping.naver.com/gate.nhn?id=...    8800            네이버
# ..                                                ...     ...    ...     ...
# 95  https://search.shopping.naver.com/gate.nhn?id=...    8800         몰스킨스토어
# 96  https://search.shopping.naver.com/gate.nhn?id=...  327800             쿠팡
# 97  https://search.shopping.naver.com/gate.nhn?id=...   22000           베스트펜
# 98  https://search.shopping.naver.com/gate.nhn?id=...   40940          유닛808
# 99  https://search.shopping.naver.com/gate.nhn?id=...   99000          펜샵코리아
#
# [1000 rows x 5 columns]

# %%
result_mol.reset_index(drop=True, inplace=True)

# %%
result_mol['lprice'] = result_mol['lprice'].astype('float')
# result_mol['hprice'] = result_mol['hprice'].astype('float')
# hprice 는 str임

# %%
writer = pd.ExcelWriter("./data/06_molskin_diary_in_naver_shop.xlsx",
                       engine='xlsxwriter')
result_mol.to_excel(writer,sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A',4)
worksheet.set_column('B:B',60)
worksheet.set_column('C:C',10)
worksheet.set_column('D:D',10)
worksheet.set_column('E:E',50)
worksheet.set_column('F:F',10)

worksheet.conditional_format('C2:C1001',{'type':'3_color_scale'})

writer.save()

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-1.3.7-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 275 kB/s eta 0:00:01
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.3.7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

# f_path = "/Library/Fonts/AppleGothic.ttf"
# font_name = font_manager.FontProperties(fname=f_path).get_name()
# rc('font',family=font_name)

# %%
plt.figure(figsize=(15,6))
sns.countplot('mall',data=result_mol, palette="RdYlGn",
             order=result_mol['mall'].value_counts().index)
plt.xticks(rotation=90)
plt.show()
# Out:
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47788 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47792 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53416 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49885 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54172 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54168 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45212 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45936 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 55193 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53584 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49789 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45787 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46028 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50725 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49496 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45348 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47788 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47792 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53416 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49885 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54172 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52852 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54168 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45212 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47215 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45936 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 55193 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53584 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52992 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49789 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45787 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50725 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/song-kang/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49496 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
body = {
    "startDate" : "2017-01-01",
    "endDate" : "2017-04-30",
    "timeUnit" : "month",
    "keywordGroups" :[
        {"groupName" : "한글", "keywords":["한글","korean"]},
        {"groupName" : "영어", "keywords":["영어","english"]}
    ],
    "device":"pc",
    "ages":["1","2"],
    "gender":"f"
}

# %%
import json

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2017-01-01",
#     "endDate": "2017-04-30",
#     "timeUnit": "month",
#     "keywordGroups": [
#         {
#             "groupName": "한글",
#             "keywords": [
#                 "한글",
#                 "korean"
#             ]
#         },
#         {
#             "groupName": "영어",
#             "keywords": [
#                 "영어",
#                 "english"
#             ]
#         }
#     ],
#     "device": "pc",
#     "ages": [
#         "1",
#         "2"
#     ],
#     "gender": "f"
# }

# %%
url = "https://openapi.naver.com/v1/datalab/search"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode('utf-8'))

json.loads(response.read().decode('utf-8'))
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
def get_trend(body):
    url = "https://openapi.naver.com/v1/datalab/search"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode('utf-8'))
    
    return json.loads(response.read().decode('utf-8'))

# %%
get_trend(body)
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
body = {
    "startDate" : "2019-01-01",
    "endDate" : "2019-04-30",
    "timeUnit":"date",
    "keywordGroups" : [
        {
            "groupName" : "타다",
            "keywords" : ["타다","쏘카","vcnc","VCNC"]
        },
    ]
}

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2019-01-01",
#     "endDate": "2019-04-30",
#     "timeUnit": "date",
#     "keywordGroups": [
#         {
#             "groupName": "타다",
#             "keywords": [
#                 "타다",
#                 "쏘카",
#                 "vcnc",
#                 "VCNC"
#             ]
#         }
#     ]
# }

# %%
tada_raw_data = get_trend(body)

# %%
tada_raw_data
# Out:
# {'startDate': '2019-01-01',
#  'endDate': '2019-04-30',
#  'timeUnit': 'date',
#  'results': [{'title': '타다',
#    'keywords': ['타다', '쏘카', 'vcnc', 'VCNC'],
#    'data': [{'period': '2019-01-01', 'ratio': 9.55311},
#     {'period': '2019-01-02', 'ratio': 12.74132},
#     {'period': '2019-01-03', 'ratio': 12.49519},
#     {'period': '2019-01-04', 'ratio': 12.72338},
#     {'period': '2019-01-05', 'ratio': 12.56057},
#     {'period': '2019-01-06', 'ratio': 10.42099},
#     {'period': '2019-01-07', 'ratio': 12.57082},
#     {'period': '2019-01-08', 'ratio': 12.13752},
#     {'period': '2019-01-09', 'ratio': 12.28495},
#     {'period': '2019-01-10', 'ratio': 13.3182},
#     {'period': '2019-01-11', 'ratio': 12.899},
#     {'period': '2019-01-12', 'ratio': 11.04402},
#     {'period': '2019-01-13', 'ratio': 9.85052},
#     {'period': '2019-01-14', 'ratio': 13.23231},
#     {'period': '2019-01-15', 'ratio': 15.47701},
#     {'period': '2019-01-16', 'ratio': 13.70791},
#     {'period': '2019-01-17', 'ratio': 13.62972},
#     {'period': '2019-01-18', 'ratio': 15.73596},
#     {'period': '2019-01-19', 'ratio': 12.70671},
#     {'period': '2019-01-20', 'ratio': 10.47739},
#     {'period': '2019-01-21', 'ratio': 14.94756},
#     {'period': '2019-01-22', 'ratio': 13.38871},
#     {'period': '2019-01-23', 'ratio': 13.00412},
#     {'period': '2019-01-24', 'ratio': 12.55929},
#     {'period': '2019-01-25', 'ratio': 12.01958},
#     {'period': '2019-01-26', 'ratio': 11.16965},
#     {'period': '2019-01-27', 'ratio': 9.69797},
#     {'period': '2019-01-28', 'ratio': 12.96566},
#     {'period': '2019-01-29', 'ratio': 12.02984},
#     {'period': '2019-01-30', 'ratio': 12.00805},
#     {'period': '2019-01-31', 'ratio': 12.35289},
#     {'period': '2019-02-01', 'ratio': 11.93626},
#     {'period': '2019-02-02', 'ratio': 10.20306},
#     {'period': '2019-02-03', 'ratio': 9.87744},
#     {'period': '2019-02-04', 'ratio': 9.04161},
#     {'period': '2019-02-05', 'ratio': 9.57362},
#     {'period': '2019-02-06', 'ratio': 11.02607},
#     {'period': '2019-02-07', 'ratio': 14.0502},
#     {'period': '2019-02-08', 'ratio': 12.59005},
#     {'period': '2019-02-09', 'ratio': 11.73755},
#     {'period': '2019-02-10', 'ratio': 10.76583},
#     {'period': '2019-02-11', 'ratio': 13.54511},
#     {'period': '2019-02-12', 'ratio': 17.75119},
#     {'period': '2019-02-13', 'ratio': 14.55144},
#     {'period': '2019-02-14', 'ratio': 14.62964},
#     {'period': '2019-02-15', 'ratio': 15.18729},
#     {'period': '2019-02-16', 'ratio': 15.79878},
#     {'period': '2019-02-17', 'ratio': 12.53749},
#     {'period': '2019-02-18', 'ratio': 47.9399},
#     {'period': '2019-02-19', 'ratio': 45.80416},
#     {'period': '2019-02-20', 'ratio': 27.11842},
#     {'period': '2019-02-21', 'ratio': 100},
#     {'period': '2019-02-22', 'ratio': 31.82575},
#     {'period': '2019-02-23', 'ratio': 16.85126},
#     {'period': '2019-02-24', 'ratio': 15.38471},
#     {'period': '2019-02-25', 'ratio': 19.4908},
#     {'period': '2019-02-26', 'ratio': 15.47573},
#     {'period': '2019-02-27', 'ratio': 15.83724},
#     {'period': '2019-02-28', 'ratio': 15.1296},
#     {'period': '2019-03-01', 'ratio': 12.98746},
#     {'period': '2019-03-02', 'ratio': 11.4645},
#     {'period': '2019-03-03', 'ratio': 10.61585},
#     {'period': '2019-03-04', 'ratio': 12.8849},
#     {'period': '2019-03-05', 'ratio': 12.53621},
#     {'period': '2019-03-06', 'ratio': 13.44896},
#     {'period': '2019-03-07', 'ratio': 18.88188},
#     {'period': '2019-03-08', 'ratio': 16.27438},
#     {'period': '2019-03-09', 'ratio': 12.04522},
#     {'period': '2019-03-10', 'ratio': 10.28638},
#     {'period': '2019-03-11', 'ratio': 12.86695},
#     {'period': '2019-03-12', 'ratio': 14.42324},
#     {'period': '2019-03-13', 'ratio': 12.16829},
#     {'period': '2019-03-14', 'ratio': 11.91575},
#     {'period': '2019-03-15', 'ratio': 11.96318},
#     {'period': '2019-03-16', 'ratio': 11.30297},
#     {'period': '2019-03-17', 'ratio': 13.62459},
#     {'period': '2019-03-18', 'ratio': 12.77722},
#     {'period': '2019-03-19', 'ratio': 14.16429},
#     {'period': '2019-03-20', 'ratio': 14.3271},
#     {'period': '2019-03-21', 'ratio': 13.46691},
#     {'period': '2019-03-22', 'ratio': 13.10796},
#     {'period': '2019-03-23', 'ratio': 10.50047},
#     {'period': '2019-03-24', 'ratio': 9.4467},
#     {'period': '2019-03-25', 'ratio': 12.53621},
#     {'period': '2019-03-26', 'ratio': 15.18472},
#     {'period': '2019-03-27', 'ratio': 15.02833},
#     {'period': '2019-03-28', 'ratio': 12.90541},
#     {'period': '2019-03-29', 'ratio': 12.49903},
#     {'period': '2019-03-30', 'ratio': 10.70174},
#     {'period': '2019-03-31', 'ratio': 12.98874},
#     {'period': '2019-04-01', 'ratio': 12.45545},
#     {'period': '2019-04-02', 'ratio': 13.72843},
#     {'period': '2019-04-03', 'ratio': 13.08745},
#     {'period': '2019-04-04', 'ratio': 13.02335},
#     {'period': '2019-04-05', 'ratio': 12.89644},
#     {'period': '2019-04-06', 'ratio': 10.70045},
#     {'period': '2019-04-07', 'ratio': 10.00692},
#     {'period': '2019-04-08', 'ratio': 13.67971},
#     {'period': '2019-04-09', 'ratio': 12.92336},
#     {'period': '2019-04-10', 'ratio': 13.03489},
#     {'period': '2019-04-11', 'ratio': 13.14386},
#     {'period': '2019-04-12', 'ratio': 12.77594},
#     {'period': '2019-04-13', 'ratio': 10.5479},
#     {'period': '2019-04-14', 'ratio': 9.72617},
#     {'period': '2019-04-15', 'ratio': 60.76583},
#     {'period': '2019-04-16', 'ratio': 17.39481},
#     {'period': '2019-04-17', 'ratio': 14.4976},
#     {'period': '2019-04-18', 'ratio': 15.02704},
#     {'period': '2019-04-19', 'ratio': 13.32589},
#     {'period': '2019-04-20', 'ratio': 10.74019},
#     {'period': '2019-04-21', 'ratio': 12.34648},
#     {'period': '2019-04-22', 'ratio': 16.1949},
#     {'period': '2019-04-23', 'ratio': 14.61682},
#     {'period': '2019-04-24', 'ratio': 13.82842},
#     {'period': '2019-04-25', 'ratio': 13.36948},
#     {'period': '2019-04-26', 'ratio': 12.73748},
#     {'period': '2019-04-27', 'ratio': 10.57867},
#     {'period': '2019-04-28', 'ratio': 10.09794},
#     {'period': '2019-04-29', 'ratio': 13.26821},
#     {'period': '2019-04-30', 'ratio': 15.56162}]}]}

# %%
tada_raw_data['results'][0]['data']
# Out:
# [{'period': '2019-01-01', 'ratio': 9.55311},
#  {'period': '2019-01-02', 'ratio': 12.74132},
#  {'period': '2019-01-03', 'ratio': 12.49519},
#  {'period': '2019-01-04', 'ratio': 12.72338},
#  {'period': '2019-01-05', 'ratio': 12.56057},
#  {'period': '2019-01-06', 'ratio': 10.42099},
#  {'period': '2019-01-07', 'ratio': 12.57082},
#  {'period': '2019-01-08', 'ratio': 12.13752},
#  {'period': '2019-01-09', 'ratio': 12.28495},
#  {'period': '2019-01-10', 'ratio': 13.3182},
#  {'period': '2019-01-11', 'ratio': 12.899},
#  {'period': '2019-01-12', 'ratio': 11.04402},
#  {'period': '2019-01-13', 'ratio': 9.85052},
#  {'period': '2019-01-14', 'ratio': 13.23231},
#  {'period': '2019-01-15', 'ratio': 15.47701},
#  {'period': '2019-01-16', 'ratio': 13.70791},
#  {'period': '2019-01-17', 'ratio': 13.62972},
#  {'period': '2019-01-18', 'ratio': 15.73596},
#  {'period': '2019-01-19', 'ratio': 12.70671},
#  {'period': '2019-01-20', 'ratio': 10.47739},
#  {'period': '2019-01-21', 'ratio': 14.94756},
#  {'period': '2019-01-22', 'ratio': 13.38871},
#  {'period': '2019-01-23', 'ratio': 13.00412},
#  {'period': '2019-01-24', 'ratio': 12.55929},
#  {'period': '2019-01-25', 'ratio': 12.01958},
#  {'period': '2019-01-26', 'ratio': 11.16965},
#  {'period': '2019-01-27', 'ratio': 9.69797},
#  {'period': '2019-01-28', 'ratio': 12.96566},
#  {'period': '2019-01-29', 'ratio': 12.02984},
#  {'period': '2019-01-30', 'ratio': 12.00805},
#  {'period': '2019-01-31', 'ratio': 12.35289},
#  {'period': '2019-02-01', 'ratio': 11.93626},
#  {'period': '2019-02-02', 'ratio': 10.20306},
#  {'period': '2019-02-03', 'ratio': 9.87744},
#  {'period': '2019-02-04', 'ratio': 9.04161},
#  {'period': '2019-02-05', 'ratio': 9.57362},
#  {'period': '2019-02-06', 'ratio': 11.02607},
#  {'period': '2019-02-07', 'ratio': 14.0502},
#  {'period': '2019-02-08', 'ratio': 12.59005},
#  {'period': '2019-02-09', 'ratio': 11.73755},
#  {'period': '2019-02-10', 'ratio': 10.76583},
#  {'period': '2019-02-11', 'ratio': 13.54511},
#  {'period': '2019-02-12', 'ratio': 17.75119},
#  {'period': '2019-02-13', 'ratio': 14.55144},
#  {'period': '2019-02-14', 'ratio': 14.62964},
#  {'period': '2019-02-15', 'ratio': 15.18729},
#  {'period': '2019-02-16', 'ratio': 15.79878},
#  {'period': '2019-02-17', 'ratio': 12.53749},
#  {'period': '2019-02-18', 'ratio': 47.9399},
#  {'period': '2019-02-19', 'ratio': 45.80416},
#  {'period': '2019-02-20', 'ratio': 27.11842},
#  {'period': '2019-02-21', 'ratio': 100},
#  {'period': '2019-02-22', 'ratio': 31.82575},
#  {'period': '2019-02-23', 'ratio': 16.85126},
#  {'period': '2019-02-24', 'ratio': 15.38471},
#  {'period': '2019-02-25', 'ratio': 19.4908},
#  {'period': '2019-02-26', 'ratio': 15.47573},
#  {'period': '2019-02-27', 'ratio': 15.83724},
#  {'period': '2019-02-28', 'ratio': 15.1296},
#  {'period': '2019-03-01', 'ratio': 12.98746},
#  {'period': '2019-03-02', 'ratio': 11.4645},
#  {'period': '2019-03-03', 'ratio': 10.61585},
#  {'period': '2019-03-04', 'ratio': 12.8849},
#  {'period': '2019-03-05', 'ratio': 12.53621},
#  {'period': '2019-03-06', 'ratio': 13.44896},
#  {'period': '2019-03-07', 'ratio': 18.88188},
#  {'period': '2019-03-08', 'ratio': 16.27438},
#  {'period': '2019-03-09', 'ratio': 12.04522},
#  {'period': '2019-03-10', 'ratio': 10.28638},
#  {'period': '2019-03-11', 'ratio': 12.86695},
#  {'period': '2019-03-12', 'ratio': 14.42324},
#  {'period': '2019-03-13', 'ratio': 12.16829},
#  {'period': '2019-03-14', 'ratio': 11.91575},
#  {'period': '2019-03-15', 'ratio': 11.96318},
#  {'period': '2019-03-16', 'ratio': 11.30297},
#  {'period': '2019-03-17', 'ratio': 13.62459},
#  {'period': '2019-03-18', 'ratio': 12.77722},
#  {'period': '2019-03-19', 'ratio': 14.16429},
#  {'period': '2019-03-20', 'ratio': 14.3271},
#  {'period': '2019-03-21', 'ratio': 13.46691},
#  {'period': '2019-03-22', 'ratio': 13.10796},
#  {'period': '2019-03-23', 'ratio': 10.50047},
#  {'period': '2019-03-24', 'ratio': 9.4467},
#  {'period': '2019-03-25', 'ratio': 12.53621},
#  {'period': '2019-03-26', 'ratio': 15.18472},
#  {'period': '2019-03-27', 'ratio': 15.02833},
#  {'period': '2019-03-28', 'ratio': 12.90541},
#  {'period': '2019-03-29', 'ratio': 12.49903},
#  {'period': '2019-03-30', 'ratio': 10.70174},
#  {'period': '2019-03-31', 'ratio': 12.98874},
#  {'period': '2019-04-01', 'ratio': 12.45545},
#  {'period': '2019-04-02', 'ratio': 13.72843},
#  {'period': '2019-04-03', 'ratio': 13.08745},
#  {'period': '2019-04-04', 'ratio': 13.02335},
#  {'period': '2019-04-05', 'ratio': 12.89644},
#  {'period': '2019-04-06', 'ratio': 10.70045},
#  {'period': '2019-04-07', 'ratio': 10.00692},
#  {'period': '2019-04-08', 'ratio': 13.67971},
#  {'period': '2019-04-09', 'ratio': 12.92336},
#  {'period': '2019-04-10', 'ratio': 13.03489},
#  {'period': '2019-04-11', 'ratio': 13.14386},
#  {'period': '2019-04-12', 'ratio': 12.77594},
#  {'period': '2019-04-13', 'ratio': 10.5479},
#  {'period': '2019-04-14', 'ratio': 9.72617},
#  {'period': '2019-04-15', 'ratio': 60.76583},
#  {'period': '2019-04-16', 'ratio': 17.39481},
#  {'period': '2019-04-17', 'ratio': 14.4976},
#  {'period': '2019-04-18', 'ratio': 15.02704},
#  {'period': '2019-04-19', 'ratio': 13.32589},
#  {'period': '2019-04-20', 'ratio': 10.74019},
#  {'period': '2019-04-21', 'ratio': 12.34648},
#  {'period': '2019-04-22', 'ratio': 16.1949},
#  {'period': '2019-04-23', 'ratio': 14.61682},
#  {'period': '2019-04-24', 'ratio': 13.82842},
#  {'period': '2019-04-25', 'ratio': 13.36948},
#  {'period': '2019-04-26', 'ratio': 12.73748},
#  {'period': '2019-04-27', 'ratio': 10.57867},
#  {'period': '2019-04-28', 'ratio': 10.09794},
#  {'period': '2019-04-29', 'ratio': 13.26821},
#  {'period': '2019-04-30', 'ratio': 15.56162}]

# %%
ratio = [each['ratio'] for each in tada_raw_data['results'][0]['data']]
ratio
# Out:
# [9.55311,
#  12.74132,
#  12.49519,
#  12.72338,
#  12.56057,
#  10.42099,
#  12.57082,
#  12.13752,
#  12.28495,
#  13.3182,
#  12.899,
#  11.04402,
#  9.85052,
#  13.23231,
#  15.47701,
#  13.70791,
#  13.62972,
#  15.73596,
#  12.70671,
#  10.47739,
#  14.94756,
#  13.38871,
#  13.00412,
#  12.55929,
#  12.01958,
#  11.16965,
#  9.69797,
#  12.96566,
#  12.02984,
#  12.00805,
#  12.35289,
#  11.93626,
#  10.20306,
#  9.87744,
#  9.04161,
#  9.57362,
#  11.02607,
#  14.0502,
#  12.59005,
#  11.73755,
#  10.76583,
#  13.54511,
#  17.75119,
#  14.55144,
#  14.62964,
#  15.18729,
#  15.79878,
#  12.53749,
#  47.9399,
#  45.80416,
#  27.11842,
#  100,
#  31.82575,
#  16.85126,
#  15.38471,
#  19.4908,
#  15.47573,
#  15.83724,
#  15.1296,
#  12.98746,
#  11.4645,
#  10.61585,
#  12.8849,
#  12.53621,
#  13.44896,
#  18.88188,
#  16.27438,
#  12.04522,
#  10.28638,
#  12.86695,
#  14.42324,
#  12.16829,
#  11.91575,
#  11.96318,
#  11.30297,
#  13.62459,
#  12.77722,
#  14.16429,
#  14.3271,
#  13.46691,
#  13.10796,
#  10.50047,
#  9.4467,
#  12.53621,
#  15.18472,
#  15.02833,
#  12.90541,
#  12.49903,
#  10.70174,
#  12.98874,
#  12.45545,
#  13.72843,
#  13.08745,
#  13.02335,
#  12.89644,
#  10.70045,
#  10.00692,
#  13.67971,
#  12.92336,
#  13.03489,
#  13.14386,
#  12.77594,
#  10.5479,
#  9.72617,
#  60.76583,
#  17.39481,
#  14.4976,
#  15.02704,
#  13.32589,
#  10.74019,
#  12.34648,
#  16.1949,
#  14.61682,
#  13.82842,
#  13.36948,
#  12.73748,
#  10.57867,
#  10.09794,
#  13.26821,
#  15.56162]

# %%
data = [each['period'] for each in tada_raw_data['results'][0]['data']]
data
# Out:
# ['2019-01-01',
#  '2019-01-02',
#  '2019-01-03',
#  '2019-01-04',
#  '2019-01-05',
#  '2019-01-06',
#  '2019-01-07',
#  '2019-01-08',
#  '2019-01-09',
#  '2019-01-10',
#  '2019-01-11',
#  '2019-01-12',
#  '2019-01-13',
#  '2019-01-14',
#  '2019-01-15',
#  '2019-01-16',
#  '2019-01-17',
#  '2019-01-18',
#  '2019-01-19',
#  '2019-01-20',
#  '2019-01-21',
#  '2019-01-22',
#  '2019-01-23',
#  '2019-01-24',
#  '2019-01-25',
#  '2019-01-26',
#  '2019-01-27',
#  '2019-01-28',
#  '2019-01-29',
#  '2019-01-30',
#  '2019-01-31',
#  '2019-02-01',
#  '2019-02-02',
#  '2019-02-03',
#  '2019-02-04',
#  '2019-02-05',
#  '2019-02-06',
#  '2019-02-07',
#  '2019-02-08',
#  '2019-02-09',
#  '2019-02-10',
#  '2019-02-11',
#  '2019-02-12',
#  '2019-02-13',
#  '2019-02-14',
#  '2019-02-15',
#  '2019-02-16',
#  '2019-02-17',
#  '2019-02-18',
#  '2019-02-19',
#  '2019-02-20',
#  '2019-02-21',
#  '2019-02-22',
#  '2019-02-23',
#  '2019-02-24',
#  '2019-02-25',
#  '2019-02-26',
#  '2019-02-27',
#  '2019-02-28',
#  '2019-03-01',
#  '2019-03-02',
#  '2019-03-03',
#  '2019-03-04',
#  '2019-03-05',
#  '2019-03-06',
#  '2019-03-07',
#  '2019-03-08',
#  '2019-03-09',
#  '2019-03-10',
#  '2019-03-11',
#  '2019-03-12',
#  '2019-03-13',
#  '2019-03-14',
#  '2019-03-15',
#  '2019-03-16',
#  '2019-03-17',
#  '2019-03-18',
#  '2019-03-19',
#  '2019-03-20',
#  '2019-03-21',
#  '2019-03-22',
#  '2019-03-23',
#  '2019-03-24',
#  '2019-03-25',
#  '2019-03-26',
#  '2019-03-27',
#  '2019-03-28',
#  '2019-03-29',
#  '2019-03-30',
#  '2019-03-31',
#  '2019-04-01',
#  '2019-04-02',
#  '2019-04-03',
#  '2019-04-04',
#  '2019-04-05',
#  '2019-04-06',
#  '2019-04-07',
#  '2019-04-08',
#  '2019-04-09',
#  '2019-04-10',
#  '2019-04-11',
#  '2019-04-12',
#  '2019-04-13',
#  '2019-04-14',
#  '2019-04-15',
#  '2019-04-16',
#  '2019-04-17',
#  '2019-04-18',
#  '2019-04-19',
#  '2019-04-20',
#  '2019-04-21',
#  '2019-04-22',
#  '2019-04-23',
#  '2019-04-24',
#  '2019-04-25',
#  '2019-04-26',
#  '2019-04-27',
#  '2019-04-28',
#  '2019-04-29',
#  '2019-04-30']

# %%
plt.figure(figsize=(18,6))
plt.plot(data,ratio)
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
tada_pd = pd.DataFrame({'data':ratio}, index=data)
tada_pd.head()
# Out:
#                 data
# 2019-01-01   9.55311
# 2019-01-02  12.74132
# 2019-01-03  12.49519
# 2019-01-04  12.72338
# 2019-01-05  12.56057

# %%
vertical_range = tada_pd[tada_pd['data']>30]
vertical_range
# Out:
#                  data
# 2019-02-18   47.93990
# 2019-02-19   45.80416
# 2019-02-21  100.00000
# 2019-02-22   31.82575
# 2019-04-15   60.76583

# %%
vertical_range.index[0],vertical_range.index[-2],vertical_range.index[-1]
# Out:
# ('2019-02-18', '2019-02-22', '2019-04-15')

# %%
vline = [vertical_range.index[0],
        vertical_range.index[-2],
        vertical_range.index[-1]]

# %%
plt.figure(figsize=(18,8))
plt.plot(data, ratio)

for each in vline:
    plt.axvline(x=each, color='black')
    
plt.grid()
plt.xticks('')
plt.show()

# %%
from random import randint

plt.figure(figsize=(18,8))
plt.plot(data, ratio)
for each in vline:
    plt.axvline(x=each, color='black')
    plt.annotate(each,xy=(each,randint(40,80)), size=15,
                arrowprops=dict(facecolor='black',shrink=0.04))

plt.xticks('')

plt.show()
